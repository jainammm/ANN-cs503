# %% [markdown]
# ##  Lab 3(a) - Implementation of Multi layer perceptron from scratch
# ##  Weightage - 2.4%
#
# Maximum Points in the Lab: 90
#
# ---
# Important points to remember :
#
#
# 1.  Observations for the experiments should be explained.
# 2. All the code should be submitted in the form of a single Jupyter notebook itself.
# 3. Points for each sub-section are mentioned in the appropriate question.
# 4. Make sure to begin early as a few experiments may consume more time to run.
# 5. You can use Google colab to run in jupyter notebook (https://colab.research.google.com/) How to load data in Google Colab ?(https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92)
# 6. The lab must be submitted on Google classroom. The code as well as the accompanying observations should be made part of the python notebook.
# 7. **Code Readability** is very important. Hence use self explanatory variable names and add comments to describe your approach wherever necessary.
# 8. You are expected to submit your **detailed inferences** and not just an error free code.
# 9. The lab is due on **March 20th 11.59pm**.
# 10. The lab should be completed **individually**. Students are expected to follow the **honor code** of the class.
#
# For any doubts regarding lab please mail to 2018csm1011@iitrpr.ac.in
#
#
# Below is the multi layer perceptron architechture used for implementation. Notations of the neural network are mentioned below :

# %% [markdown]
# ![MLP implementation diagram](pictures/mlp.png)

# %% [markdown]
# ## Implementation details :
#
# 1) In this lab you will be using MLP for classifying MNIST digits. a. Let us consider a MLP network with H hidden units, O outputs, and
# inputs of size D.
#
# 2) According to above diagram dimensions of network will be :
# ```
#  W - H * D+1   -- Weights from Input layer to Hidden layer
#  V - K * H+1   -- Weights from Hidden layer to Output layer
#  X - N * D+1   -- Weights of Input data
#  Y - N * K     -- Weights of Output label data
#  Z - H+1 * 1   -- Hidden layer Weights
#  O - K * 1     -- Output layer weights
# ```
# 3) Please note that +1 in above notations is to indicate bias term.
#
# 4) tanh is used as the activation function.
#
# 5) During forward pass will be :
#
# $\mathbf{z}=\tanh (\mathbf{W} \mathbf{x})$
#
# and $O_{i}=\frac{\exp v_{i}^{T} z}{\sum_{k=1}^{K} \exp v_{k}^{T} z}$
#
# Overall loss function will be :
#
# Total loss = $-\sum_{n=1}^{N} \sum_{i=1}^{K} y_{n i} \log O_{n i}$

# %% [markdown]
# 6) The dataset is included in zip file ("data.txt" and "label.txt"). Number of hidden layer units to be 500, learning rate is set to be 0.01.
#
# 7) Inorder to update the weights during back propogation we will modified version of stochastic gradient descent, where instead of updating weights after each data point, the updates are made once with batch of input data, Let batch size = 25. Number of epochs = 100.
#
# 8) Divide the data into train, validation, and test splits using a preset ratio. Please define the ratio you are using.
#
# 9) Please plot the below :
#
#     i)  Training error, Validation error Vs epochs [average over 5 runs.]
#
#     ii) Mean Training error Vs epochs [average over 5 runs.]
#
#     iii)  Mean Validation error Vs epochs [average over 5 runs.]
#
#     iv) Variance Training error Vs epochs [average over 5 runs.]
#
#      v)  Variance validation error Vs epochs [average over 5 runs.]

# %% [markdown]
# # Note :
#
# 1) All weight update equations during back propogation should be done using $\textbf{Matrix operations}$ only (not for loops).
#
#  For example :
#
# ![MLP implementation diagram](pictures/equation.png)

# %% [markdown]
# # Maximum points : 90 points.
#
# 1) Derive the weight update equation for W in form of Matrix operations similar to V matrix operations defined above.(write in the jupyter notebook itself using Latex or image) - 10 pts
#
# ![W update Eqn](pictures/W_update.jpeg)
#
# 2) Splitting train, validation and test using preset ratio - 5 pts
#
# 3) Random weights assign to W,V values -  5 pts.
#
# 4) During Forward pass :
#
#        updating Z values - 5 pts.
#
#        updating O values - 5 pts.
#
#        Applying softmax values - 5pts.
#
#        Calculating error values - 5pts.
#
# 5) During backward pass : ( only matrix operations allowed)
#
#        Gradient between hidden to output - 10 pts.
#
#        Gradient betweem input to hidden - 15 pts.
#
# 6) Using batch size = 25 to update weights - 5 pts.
#
# 7) averaging over 5 runs - 5 pts.
#
# 8) Please plot the below : - 10pts.
#
#     i)  Training error, Validation error Vs epochs [average over 5 runs.]
#
#     ii) Mean Training error Vs epochs [average over 5 runs.]
#
#     iii)  Mean Validation error Vs epochs [average over 5 runs.]
#
#     iv) Variance Training error Vs epochs [average over 5 runs.]
#
#      v)  Variance validation error Vs epochs [average over 5 runs.]
#
# 9) Discuss the observations from above plots. - 5pts.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

####################################################################################
# Derivative of weights as defined in Lab3.a	####################################
####################################################################################
####################################################################################

# Dimension of all the Matrices Used
# W - H * D+1   -- Weights from Input layer to Hidden layer
# V - K * H+1   -- Weights from Hidden layer to Output layer
# X - N * D+1   -- Weights of Input data
# Y - N * K     -- Weights of Output label data
# Z - H+1 * 1   -- Hidden layer Weights
# O - K * 1     -- Output layer weights


# Function to read data and store it in form of 2D array
def read_data(file_name) :
    data = np.loadtxt(file_name, delimiter=',')
    return data


# Implementation of Forward pass function
def forward_pass(data_points,W,V,Y) :
    # use compute_Z_values, compute_O_values, compute_softmax, calculate_error to compute error, O_softmax
    # During forward pass compute Z values, O_values, O_softmax, error
    # Insert code here
    Z = compute_Z_values(W, data_points)
    O = compute_O_values(V, Z)
    O_softmax = compute_softmax(O)
    error = calculate_error(O_softmax, Y)

    #return the error, O_softmax
    return error, O_softmax


# Implementation of Cross Entropy Error Function takes as input O_softmax, Y
def calculate_error(predictions, targets, epsilon=1e-10):
    # Caculate cross entropy error between output of softmax (predictions) , actual values (targets)
    #Insert code here
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    cross_entropy_error = - np.sum(targets * np.log(predictions)) / predictions.shape[0]

    #returns cross entropy error
    return cross_entropy_error


# Implementation of Softmax Error Function takes as input O
def compute_softmax(output_matrix) :
    # return output_matrix after apply softmax function ( hint: use np.exp function )
    y_length = 10
    #Insert code here
    for i in range(len(output_matrix)):
        output_matrix[i] = np.exp(output_matrix[i] - np.max(output_matrix[i]))
        output_matrix[i] /= np.sum(output_matrix[i])

    # returns output_matrix
    return output_matrix


# Implementation of Backward pass using Backpropagation Algorithm to calculate V_new, W_new, bias_v
def backward_pass(O_softmax,Y,V,Z,W,X,bias_z):
    # use gradient_hidden_to_output, gradient_input_to_hidden functions to compute V_new, bias_v, W_new 
    #Insert code here
    V_new, bias_v = gradient_hidden_to_output(O_softmax, Y, Z, bias_z)
    W_new = gradient_input_to_hidden(O_softmax, Y, V, Z, X)

    #returns V_new, W_new, bias_v
    return  W_new, V_new, bias_v


#Implementation of Graident back propogation from Hidden to Input Layer
def gradient_hidden_to_output(O_softmax,Y,Z,bias_z) :
    # function to update V values using backpropogation using matrix operations.
    #Insert code here
    Z_ = initilaise_weights(Z.T).T
    final_result_matrix = np.dot((O_softmax - Y).T, Z_.T)
    bias_v = final_result_matrix.T[final_result_matrix.shape[1]-1]
    final_result_matrix = final_result_matrix[..., :-1]
    bias_v = bias_v.reshape((bias_v.shape[0], 1))

    return final_result_matrix, bias_v

#Implementation of Graident back propogation from Input to Hidden Layer
def gradient_input_to_hidden(O_softmax,Y,V,Z,X) :
    # function to update W values using backpropogation using only matrix operations.
    #Insert code here
    z_ = np.ones(Z.shape) - Z*Z
    z_ = np.mean(z_, axis=1)
    V = V[:, :V.shape[1]-1]
    result_matrix = np.dot(np.dot(X.T,O_softmax - Y), V*z_)
    
    # returns updated W values
    return result_matrix.T



# Function to calculate Z values during forward pass
def compute_Z_values(weights,data_points) :
    # function to update Z during forward pass using matrix operations.
    #Insert code here
    z_values = np.dot(weights, data_points.T)
    z_values = np.tanh(z_values)

    #return calculated z_values
    return z_values


# Function to Calculate output matrix during forward pass
def compute_O_values(weights,z_values) :
    # function to update O during forward pass using matrix operations.
    #Insert code here
    o_values = np.dot(weights, initilaise_weights(z_values.T).T)

    #return calculated o_values
    return o_values.T



# Function to Intialise weights with bias term
def initilaise_weights(data) :
    # function to append bias term.
    # insert code here
    rows, cols = data.shape
    biasColumn = np.ones(shape = (rows, 1))
    final_data = np.concatenate((data, biasColumn), axis=1)

    return final_data



# To intiliase random weights to Matrices such as W, V
def random_weights(number_of_rows,number_of_columns) :
    # Function to assign random weights to W, V
    #Insert code here 
    new_data = np.random.randn(number_of_rows, number_of_columns)

    # return random weights with number_of_rows * number_of_columns
    return new_data


# To divide the data into test train data
def train_test_split(X,Y,fraction) :
    # Function to divide train, validation and test data based on fraction. let fraction = 0.8 then train = 0.75, validation= 0.05 and test = 0.2 
    #Insert code here 
    
    shuffledX, shuffledY = shuffle(X, Y, 107)
    testFraction = 1 - fraction
    
    test_data_x, validation_data_x, data_train_x = np.split(X, [int(testFraction * len(X)), 
                                                        int((testFraction + testFraction*testFraction) * len(X))])
    
    
    test_data_y, validation_data_y, data_train_y = np.split(Y, [int(testFraction * len(Y)), 
                                                        int((testFraction + testFraction*testFraction) * len(Y))])
    
    # return data_train_x,data_train_y,validation_data_x,validation_data_y,test_data_x,test_data_y
    return data_train_x,data_train_y,validation_data_x,validation_data_y,test_data_x,test_data_y


# Shuffle in same order for X,Y
def shuffle(a, b, seed): 
#     temp = list(zip(a, b))
    
#     random.seed(seed)
#     random.shuffle(temp)
    
#     a, b = zip(*temp)
    
    indices = np.arange(a.shape[0])
    
    random.seed(seed)
    np.random.shuffle(indices)
    
    a = a[indices]
    b = b[indices]


    # return shuffled values a,b in same order
    return a,b


if __name__ == "__main__" :
    data = read_data("data.txt")
    Y = read_data("label.txt")
    X = initilaise_weights(data)
    W = random_weights(500,401)
    V = random_weights(10,501)
    Z = compute_Z_values(W,X[:25,:])
    O = compute_O_values(V,Z)
    bias_z = np.empty(shape=(25, 1))
    bias_z.fill(1.0)
    i=0
    learning_rate = 0.01
    train_test_fraction  = 0.8
    train_validation_split = 0.2
    train_data_x,train_data_y,validation_data_x,validation_data_y,test_data_x,test_data_y =train_test_split(X,Y,train_test_fraction)
    number_of_epocs=100
    train_error_epoch = []*(5*number_of_epocs)
    #X = train_data_x
    #Y = train_data_y
    #Dividing the data into training data and test data into 0.8 ratio same ration for train and validation data,values below correspond to 0.8 ratio
    train_data_len = 3200
    validation_data_len = 800
    test_data_len =1000
    validation_error_epoch = [] * (5*number_of_epocs)
    # Running for 5 trails using 100 Epocs and Batch size = 25
    batch_size = 25
    print("Started calculating Training error in 5 Trails for each epoch with Batch size = 25 ")
    print("Started calculating Validation error in 5 Trails for each epoch with Batch size = 25 ")
    # Different trails are performed for 5 times.
    # 5 different trails
    trails = 5
    for k in range(trails) :
        W = random_weights(500, 401)
        V = random_weights(10, 501)
        error_train=0
        error_validation = 0
        # Randomising the data
        seed = random.randint(10000,10000000)
        X,Y = shuffle(X,Y,seed)
        print("Training Error for 100th epoch for Trail Number : "+str(k+1))
        for j in range(number_of_epocs) :
            i=0
            error_train = 0.0
            error_validation = 0.0
            count = 0
            #X,Y = shuffle(X,Y,12345)
            while i < (train_data_len)  :
                i1=i
                # Batch size is 25
                i= i+25
                error,O_softmax=forward_pass(X[i1:i, :], W, V, Y[i1:i, :])
                W_new,V_new,bias_v=backward_pass(O_softmax,Y[i1:i,:],V,Z,W,X[i1:i,:],bias_z)
                #print(W_new.shape)
                W = W - (learning_rate/25)*W_new
                #print(W)
                V_new = np.append(learning_rate*bias_v,V_new,axis=1)
                V = V - (learning_rate/25)*V_new
                error_train+= error
                count+=1
                #print(error1)
                #print(V.shape)
            #print(error)
            #print(j)
            error, O_softmax = forward_pass(X[0:3200, :], W, V, Y[0 : 3200, :])
            error1, O_softmax = forward_pass(X[3200:4000, :], W, V, Y[3200:4000, :])
            print
            error_validation = error1
            count = train_data_len/batch_size
            count1= validation_data_len/batch_size
            error_train = error_train/count
            print("Training error after  epoch : "+str(j+1)+" here every batch size = 25")
            print(error_train)
            print("Validation error after  epoch : "+str(j+1)+" here batch size = 25")
            print(error_validation)
            train_error_epoch.append(error_train)
            validation_error_epoch.append(error_validation)
    print("\n")
    print("Final Training Errors after 5 trails and 100 Epocs : ")
    print(train_error_epoch)
    print("\n")
    print("Final Validation Errors after 5 trails and 100 Epocs : ")
    print(validation_error_epoch)
    mean_training = []
    variance_training = []
    mean_validation = []
    variance_validation = []
    train_error_epoch = np.reshape(train_error_epoch,(trails,number_of_epocs))
    validation_error_epoch = np.reshape(validation_error_epoch,(trails,number_of_epocs))
    mean_training = np.mean(train_error_epoch, axis=0)
    mean_validation = np.mean(validation_error_epoch,axis=0)
    variance_training = np.var(train_error_epoch,axis=0)
    variance_validation = np.var(validation_error_epoch,axis=0)
    mean_training = np.reshape(mean_training,(number_of_epocs,))
    mean_validation = np.reshape(mean_validation, (number_of_epocs))
    variance_training = np.reshape(variance_training,(number_of_epocs,))
    variance_validation = np.reshape(variance_validation,(number_of_epocs,))
    epochs = []
    for i in range(1,number_of_epocs+1) :
        epochs.append(i)
    print("\n")
    print("Plots are started to Generate In Figures Folder : ")
    plt.plot(epochs,mean_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    #plt.title("Plot for Training Error Vs Epochs")
    location = "./figures/lab3.a_TrainingError" + ".png"
    #plt.savefig(location)
    #plt.close()
    plt.plot(epochs, mean_validation,color='blue', label='Validation')
    plt.ylabel("Training,Validation Error values")
    plt.title("Plot for Training,Validation Error Vs Epochs")
    plt.legend(loc='best')
    location = "./figures/lab3.a_TrainingAndValidationError" + ".png"
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.0145,0.01465)
    plt.plot(epochs, mean_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    plt.ylabel("Mean Training Error values")
    plt.title("Plot for Mean Training Error Vs Epochs")
    location = "./figures/lab3.a_MeanTrainingError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.0133, 0.134)
    plt.plot(epochs, mean_validation, color='blue', label='Validation')
    plt.xlabel("Epoch values")
    plt.ylabel(" Mean Validation Error values")
    plt.title("Plot for Mean Validation Error Vs Epochs")
    location = "./figures/lab3.a_MeanValidationError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.000240, 0.000242)
    plt.plot(epochs, variance_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    plt.ylabel(" Variance Training Error values")
    plt.title("Plot for Variance Training Error Vs Epochs")
    location = "./figures/lab3.a_VarianceTrainingError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.000210, 0.000211)
    plt.plot(epochs, variance_validation, color='blue', label='Validation')
    plt.xlabel("Epoch values")
    plt.ylabel("Variance Validation Error values")
    plt.title("Plot for Variance Validation Error Vs Epochs")
    location = "./figures/lab3.a_VarianceValidationError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    print("\n")
    print("Plots are Generated Successfully In Figures folder")
# Out:
# Started calculating Training error in 5 Trails for each epoch with Batch size = 25
# Started calculating Validation error in 5 Trails for each epoch with Batch size = 25
# Training Error for 100th epoch for Trail Number : 1
# Training error after  epoch : 1 here every batch size = 25
# 15.035148477290713
# Validation error after  epoch : 1 here batch size = 25
# 13.13189156488082
# Training error after  epoch : 2 here every batch size = 25
# 12.509590973247297
# Validation error after  epoch : 2 here batch size = 25
# 11.172910178083995
# Training error after  epoch : 3 here every batch size = 25
# 10.977932048299397
# Validation error after  epoch : 3 here batch size = 25
# 9.794883399075434
# Training error after  epoch : 4 here every batch size = 25
# 9.719523076430104
# Validation error after  epoch : 4 here batch size = 25
# 8.733528150885483
# Training error after  epoch : 5 here every batch size = 25
# 8.665632161595468
# Validation error after  epoch : 5 here batch size = 25
# 7.906000090238052
# Training error after  epoch : 6 here every batch size = 25
# 7.809166389523898
# Validation error after  epoch : 6 here batch size = 25
# 7.24362216216624
# Training error after  epoch : 7 here every batch size = 25
# 7.1161411505915115
# Validation error after  epoch : 7 here batch size = 25
# 6.740421495869243
# Training error after  epoch : 8 here every batch size = 25
# 6.569285030050049
# Validation error after  epoch : 8 here batch size = 25
# 6.3537766753021545
# Training error after  epoch : 9 here every batch size = 25
# 6.122572354432831
# Validation error after  epoch : 9 here batch size = 25
# 6.03328080824811
# Training error after  epoch : 10 here every batch size = 25
# 5.750887771739003
# Validation error after  epoch : 10 here batch size = 25
# 5.760416267893245
# Training error after  epoch : 11 here every batch size = 25
# 5.436156946093576
# Validation error after  epoch : 11 here batch size = 25
# 5.526327412408725
# Training error after  epoch : 12 here every batch size = 25
# 5.166022185992461
# Validation error after  epoch : 12 here batch size = 25
# 5.320306189115524
# Training error after  epoch : 13 here every batch size = 25
# 4.935279869863837
# Validation error after  epoch : 13 here batch size = 25
# 5.139952524213031
# Training error after  epoch : 14 here every batch size = 25
# 4.736297638998033
# Validation error after  epoch : 14 here batch size = 25
# 4.981741984105906
# Training error after  epoch : 15 here every batch size = 25
# 4.563400108376681
# Validation error after  epoch : 15 here batch size = 25
# 4.844302757963496
# Training error after  epoch : 16 here every batch size = 25
# 4.412046098989488
# Validation error after  epoch : 16 here batch size = 25
# 4.7257190073262585
# Training error after  epoch : 17 here every batch size = 25
# 4.277767575803647
# Validation error after  epoch : 17 here batch size = 25
# 4.619341671105278
# Training error after  epoch : 18 here every batch size = 25
# 4.158904555040648
# Validation error after  epoch : 18 here batch size = 25
# 4.5248561264113825
# Training error after  epoch : 19 here every batch size = 25
# 4.054342082927707
# Validation error after  epoch : 19 here batch size = 25
# 4.440494324181205
# Training error after  epoch : 20 here every batch size = 25
# 3.9612580493867915
# Validation error after  epoch : 20 here batch size = 25
# 4.363342670276551
# Training error after  epoch : 21 here every batch size = 25
# 3.87788874805065
# Validation error after  epoch : 21 here batch size = 25
# 4.29221135030702
# Training error after  epoch : 22 here every batch size = 25
# 3.802063738297518
# Validation error after  epoch : 22 here batch size = 25
# 4.2260904092552405
# Training error after  epoch : 23 here every batch size = 25
# 3.732303009708832
# Validation error after  epoch : 23 here batch size = 25
# 4.165062607262018
# Training error after  epoch : 24 here every batch size = 25
# 3.667084704812948
# Validation error after  epoch : 24 here batch size = 25
# 4.1083875894205
# Training error after  epoch : 25 here every batch size = 25
# 3.606444703138594
# Validation error after  epoch : 25 here batch size = 25
# 4.056104796298605
# Training error after  epoch : 26 here every batch size = 25
# 3.549717371759913
# Validation error after  epoch : 26 here batch size = 25
# 4.007908751191278
# Training error after  epoch : 27 here every batch size = 25
# 3.496006825589465
# Validation error after  epoch : 27 here batch size = 25
# 3.963106043390033
# Training error after  epoch : 28 here every batch size = 25
# 3.4452633226779
# Validation error after  epoch : 28 here batch size = 25
# 3.9210480661622342
# Training error after  epoch : 29 here every batch size = 25
# 3.3976074227549105
# Validation error after  epoch : 29 here batch size = 25
# 3.881244236869778
# Training error after  epoch : 30 here every batch size = 25
# 3.35242821600751
# Validation error after  epoch : 30 here batch size = 25
# 3.843394675248945
# Training error after  epoch : 31 here every batch size = 25
# 3.309594802942415
# Validation error after  epoch : 31 here batch size = 25
# 3.807811189987602
# Training error after  epoch : 32 here every batch size = 25
# 3.26895473541184
# Validation error after  epoch : 32 here batch size = 25
# 3.7742484515367196
# Training error after  epoch : 33 here every batch size = 25
# 3.2300906311302224
# Validation error after  epoch : 33 here batch size = 25
# 3.742447512615781
# Training error after  epoch : 34 here every batch size = 25
# 3.1930947707009714
# Validation error after  epoch : 34 here batch size = 25
# 3.712420403737955
# Training error after  epoch : 35 here every batch size = 25
# 3.157968455502616
# Validation error after  epoch : 35 here batch size = 25
# 3.6840358332834815
# Training error after  epoch : 36 here every batch size = 25
# 3.1243162266466635
# Validation error after  epoch : 36 here batch size = 25
# 3.6570474242935744
# Training error after  epoch : 37 here every batch size = 25
# 3.091910186822356
# Validation error after  epoch : 37 here batch size = 25
# 3.631371215578394
# Training error after  epoch : 38 here every batch size = 25
# 3.0605161233728198
# Validation error after  epoch : 38 here batch size = 25
# 3.606749586599628
# Training error after  epoch : 39 here every batch size = 25
# 3.0302500913151356
# Validation error after  epoch : 39 here batch size = 25
# 3.583550815432626
# Training error after  epoch : 40 here every batch size = 25
# 3.001330606444125
# Validation error after  epoch : 40 here batch size = 25
# 3.5614102772035867
# Training error after  epoch : 41 here every batch size = 25
# 2.973666934705742
# Validation error after  epoch : 41 here batch size = 25
# 3.539955822433127
# Training error after  epoch : 42 here every batch size = 25
# 2.9469724717736967
# Validation error after  epoch : 42 here batch size = 25
# 3.5194967339008567
# Training error after  epoch : 43 here every batch size = 25
# 2.921314547348916
# Validation error after  epoch : 43 here batch size = 25
# 3.4998684968397753
# Training error after  epoch : 44 here every batch size = 25
# 2.8963560455616375
# Validation error after  epoch : 44 here batch size = 25
# 3.4808061407992286
# Training error after  epoch : 45 here every batch size = 25
# 2.8721428449323705
# Validation error after  epoch : 45 here batch size = 25
# 3.4623219844667505
# Training error after  epoch : 46 here every batch size = 25
# 2.8486628241056104
# Validation error after  epoch : 46 here batch size = 25
# 3.4445449256273077
# Training error after  epoch : 47 here every batch size = 25
# 2.825975693685249
# Validation error after  epoch : 47 here batch size = 25
# 3.427498121631924
# Training error after  epoch : 48 here every batch size = 25
# 2.803669371749432
# Validation error after  epoch : 48 here batch size = 25
# 3.4111470113002826
# Training error after  epoch : 49 here every batch size = 25
# 2.781812462343105
# Validation error after  epoch : 49 here batch size = 25
# 3.3952825128356072
# Training error after  epoch : 50 here every batch size = 25
# 2.7606612731895397
# Validation error after  epoch : 50 here batch size = 25
# 3.380072972787017
# Training error after  epoch : 51 here every batch size = 25
# 2.7401625912026515
# Validation error after  epoch : 51 here batch size = 25
# 3.3655630852291405
# Training error after  epoch : 52 here every batch size = 25
# 2.7203335227665355
# Validation error after  epoch : 52 here batch size = 25
# 3.351515570707935
# Training error after  epoch : 53 here every batch size = 25
# 2.7011786028934526
# Validation error after  epoch : 53 here batch size = 25
# 3.337834871557382
# Training error after  epoch : 54 here every batch size = 25
# 2.682567987946335
# Validation error after  epoch : 54 here batch size = 25
# 3.324513223668027
# Training error after  epoch : 55 here every batch size = 25
# 2.664470604361364
# Validation error after  epoch : 55 here batch size = 25
# 3.311850322329742
# Training error after  epoch : 56 here every batch size = 25
# 2.646963533600637
# Validation error after  epoch : 56 here batch size = 25
# 3.2998923057479828
# Training error after  epoch : 57 here every batch size = 25
# 2.6299901683520637
# Validation error after  epoch : 57 here batch size = 25
# 3.2885859310442758
# Training error after  epoch : 58 here every batch size = 25
# 2.6135289257746916
# Validation error after  epoch : 58 here batch size = 25
# 3.2778741334647474
# Training error after  epoch : 59 here every batch size = 25
# 2.597560293711018
# Validation error after  epoch : 59 here batch size = 25
# 3.267567387139553
# Training error after  epoch : 60 here every batch size = 25
# 2.582049326082986
# Validation error after  epoch : 60 here batch size = 25
# 3.257549644762139
# Training error after  epoch : 61 here every batch size = 25
# 2.566931991528083
# Validation error after  epoch : 61 here batch size = 25
# 3.247904312824978
# Training error after  epoch : 62 here every batch size = 25
# 2.552182628404455
# Validation error after  epoch : 62 here batch size = 25
# 3.238579296886148
# Training error after  epoch : 63 here every batch size = 25
# 2.537710118550472
# Validation error after  epoch : 63 here batch size = 25
# 3.229647884624518
# Training error after  epoch : 64 here every batch size = 25
# 2.5235751870021152
# Validation error after  epoch : 64 here batch size = 25
# 3.2210875464932784
# Training error after  epoch : 65 here every batch size = 25
# 2.5097341239420627
# Validation error after  epoch : 65 here batch size = 25
# 3.212877236932726
# Training error after  epoch : 66 here every batch size = 25
# 2.4962667861813896
# Validation error after  epoch : 66 here batch size = 25
# 3.2047251719900727
# Training error after  epoch : 67 here every batch size = 25
# 2.483139691021422
# Validation error after  epoch : 67 here batch size = 25
# 3.196531811953491
# Training error after  epoch : 68 here every batch size = 25
# 2.4704162460885115
# Validation error after  epoch : 68 here batch size = 25
# 3.1884981124280807
# Training error after  epoch : 69 here every batch size = 25
# 2.458046086167298
# Validation error after  epoch : 69 here batch size = 25
# 3.180740175915766
# Training error after  epoch : 70 here every batch size = 25
# 2.4458964144321107
# Validation error after  epoch : 70 here batch size = 25
# 3.1732383909619957
# Training error after  epoch : 71 here every batch size = 25
# 2.4341496534867724
# Validation error after  epoch : 71 here batch size = 25
# 3.1659771142833035
# Training error after  epoch : 72 here every batch size = 25
# 2.42280137053518
# Validation error after  epoch : 72 here batch size = 25
# 3.158944756810038
# Training error after  epoch : 73 here every batch size = 25
# 2.411796370808178
# Validation error after  epoch : 73 here batch size = 25
# 3.1519073196674956
# Training error after  epoch : 74 here every batch size = 25
# 2.4010890871215604
# Validation error after  epoch : 74 here batch size = 25
# 3.1449293771521183
# Training error after  epoch : 75 here every batch size = 25
# 2.3907231885125553
# Validation error after  epoch : 75 here batch size = 25
# 3.138112103410458
# Training error after  epoch : 76 here every batch size = 25
# 2.380696032958309
# Validation error after  epoch : 76 here batch size = 25
# 3.131407214805385
# Training error after  epoch : 77 here every batch size = 25
# 2.3709584038755547
# Validation error after  epoch : 77 here batch size = 25
# 3.1247505368174218
# Training error after  epoch : 78 here every batch size = 25
# 2.3613857081964915
# Validation error after  epoch : 78 here batch size = 25
# 3.1182704847445324
# Training error after  epoch : 79 here every batch size = 25
# 2.3520024932348025
# Validation error after  epoch : 79 here batch size = 25
# 3.1119855800098235
# Training error after  epoch : 80 here every batch size = 25
# 2.3429015673516616
# Validation error after  epoch : 80 here batch size = 25
# 3.1058808288368063
# Training error after  epoch : 81 here every batch size = 25
# 2.334044170801763
# Validation error after  epoch : 81 here batch size = 25
# 3.0998210169993103
# Training error after  epoch : 82 here every batch size = 25
# 2.325365029801194
# Validation error after  epoch : 82 here batch size = 25
# 3.093315950508406
# Training error after  epoch : 83 here every batch size = 25
# 2.316762525882853
# Validation error after  epoch : 83 here batch size = 25
# 3.086951269579115
# Training error after  epoch : 84 here every batch size = 25
# 2.308363922802357
# Validation error after  epoch : 84 here batch size = 25
# 3.0807151558861854
# Training error after  epoch : 85 here every batch size = 25
# 2.3002052603629695
# Validation error after  epoch : 85 here batch size = 25
# 3.074597000830597
# Training error after  epoch : 86 here every batch size = 25
# 2.2922370613979504
# Validation error after  epoch : 86 here batch size = 25
# 3.068587488415953
# Training error after  epoch : 87 here every batch size = 25
# 2.2844647370358713
# Validation error after  epoch : 87 here batch size = 25
# 3.0625926966759964
# Training error after  epoch : 88 here every batch size = 25
# 2.2768111226075307
# Validation error after  epoch : 88 here batch size = 25
# 3.056646468199584
# Training error after  epoch : 89 here every batch size = 25
# 2.2693558241587866
# Validation error after  epoch : 89 here batch size = 25
# 3.0507905273537723
# Training error after  epoch : 90 here every batch size = 25
# 2.2620319345827453
# Validation error after  epoch : 90 here batch size = 25
# 3.045020103171952
# Training error after  epoch : 91 here every batch size = 25
# 2.25485563126031
# Validation error after  epoch : 91 here batch size = 25
# 3.0393318948733428
# Training error after  epoch : 92 here every batch size = 25
# 2.2477870910209146
# Validation error after  epoch : 92 here batch size = 25
# 3.0337242861933453
# Training error after  epoch : 93 here every batch size = 25
# 2.240825235419017
# Validation error after  epoch : 93 here batch size = 25
# 3.0281974175368407
# Training error after  epoch : 94 here every batch size = 25
# 2.234028758596041
# Validation error after  epoch : 94 here batch size = 25
# 3.0227530792573334
# Training error after  epoch : 95 here every batch size = 25
# 2.227402985360045
# Validation error after  epoch : 95 here batch size = 25
# 3.0173944836990616
# Training error after  epoch : 96 here every batch size = 25
# 2.220953403885846
# Validation error after  epoch : 96 here batch size = 25
# 3.0121260369886445
# Training error after  epoch : 97 here every batch size = 25
# 2.2146768830657977
# Validation error after  epoch : 97 here batch size = 25
# 3.006953240109234
# Training error after  epoch : 98 here every batch size = 25
# 2.2085247129648806
# Validation error after  epoch : 98 here batch size = 25
# 3.0018827827623977
# Training error after  epoch : 99 here every batch size = 25
# 2.2025227778579537
# Validation error after  epoch : 99 here batch size = 25
# 2.9969227521236443
# Training error after  epoch : 100 here every batch size = 25
# 2.196685676794994
# Validation error after  epoch : 100 here batch size = 25
# 2.992082727962585
# Training Error for 100th epoch for Trail Number : 2
# Training error after  epoch : 1 here every batch size = 25
# 16.604653421333307
# Validation error after  epoch : 1 here batch size = 25
# 15.146409138754342
# Training error after  epoch : 2 here every batch size = 25
# 14.483851386409208
# Validation error after  epoch : 2 here batch size = 25
# 13.115983811018323
# Training error after  epoch : 3 here every batch size = 25
# 12.658947958663243
# Validation error after  epoch : 3 here batch size = 25
# 11.51045177897779
# Training error after  epoch : 4 here every batch size = 25
# 11.145503488396376
# Validation error after  epoch : 4 here batch size = 25
# 10.170462244669725
# Training error after  epoch : 5 here every batch size = 25
# 9.917926456276899
# Validation error after  epoch : 5 here batch size = 25
# 9.048410989934782
# Training error after  epoch : 6 here every batch size = 25
# 8.902804646501902
# Validation error after  epoch : 6 here batch size = 25
# 8.133277103842609
# Training error after  epoch : 7 here every batch size = 25
# 8.071518304935216
# Validation error after  epoch : 7 here batch size = 25
# 7.375685066697888
# Training error after  epoch : 8 here every batch size = 25
# 7.3871690333412126
# Validation error after  epoch : 8 here batch size = 25
# 6.769128919644472
# Training error after  epoch : 9 here every batch size = 25
# 6.82188433867916
# Validation error after  epoch : 9 here batch size = 25
# 6.280949789387007
# Training error after  epoch : 10 here every batch size = 25
# 6.348734752031685
# Validation error after  epoch : 10 here batch size = 25
# 5.882377391644492
# Training error after  epoch : 11 here every batch size = 25
# 5.957771882581695
# Validation error after  epoch : 11 here batch size = 25
# 5.554890731057574
# Training error after  epoch : 12 here every batch size = 25
# 5.626322626928118
# Validation error after  epoch : 12 here batch size = 25
# 5.28213889009394
# Training error after  epoch : 13 here every batch size = 25
# 5.342097300724044
# Validation error after  epoch : 13 here batch size = 25
# 5.045703084847554
# Training error after  epoch : 14 here every batch size = 25
# 5.097115162942952
# Validation error after  epoch : 14 here batch size = 25
# 4.837475668550588
# Training error after  epoch : 15 here every batch size = 25
# 4.883042392864356
# Validation error after  epoch : 15 here batch size = 25
# 4.657077543189672
# Training error after  epoch : 16 here every batch size = 25
# 4.692513075480668
# Validation error after  epoch : 16 here batch size = 25
# 4.494775006824133
# Training error after  epoch : 17 here every batch size = 25
# 4.521225999905283
# Validation error after  epoch : 17 here batch size = 25
# 4.349563247844168
# Training error after  epoch : 18 here every batch size = 25
# 4.368213718949932
# Validation error after  epoch : 18 here batch size = 25
# 4.217809414747726
# Training error after  epoch : 19 here every batch size = 25
# 4.2306183558977954
# Validation error after  epoch : 19 here batch size = 25
# 4.101705568152371
# Training error after  epoch : 20 here every batch size = 25
# 4.105109868822413
# Validation error after  epoch : 20 here batch size = 25
# 3.9975013610739847
# Training error after  epoch : 21 here every batch size = 25
# 3.9910572825709774
# Validation error after  epoch : 21 here batch size = 25
# 3.9025343828406505
# Training error after  epoch : 22 here every batch size = 25
# 3.8865598974073565
# Validation error after  epoch : 22 here batch size = 25
# 3.815672703951351
# Training error after  epoch : 23 here every batch size = 25
# 3.7897595384175533
# Validation error after  epoch : 23 here batch size = 25
# 3.737010613898635
# Training error after  epoch : 24 here every batch size = 25
# 3.700072633970548
# Validation error after  epoch : 24 here batch size = 25
# 3.6651968289203256
# Training error after  epoch : 25 here every batch size = 25
# 3.616600189032402
# Validation error after  epoch : 25 here batch size = 25
# 3.599124987269755
# Training error after  epoch : 26 here every batch size = 25
# 3.538893253061529
# Validation error after  epoch : 26 here batch size = 25
# 3.537736505755431
# Training error after  epoch : 27 here every batch size = 25
# 3.4653858807053797
# Validation error after  epoch : 27 here batch size = 25
# 3.4805742505550405
# Training error after  epoch : 28 here every batch size = 25
# 3.3968309340098695
# Validation error after  epoch : 28 here batch size = 25
# 3.427651804124429
# Training error after  epoch : 29 here every batch size = 25
# 3.3330371512891266
# Validation error after  epoch : 29 here batch size = 25
# 3.3779244322481192
# Training error after  epoch : 30 here every batch size = 25
# 3.273105702565148
# Validation error after  epoch : 30 here batch size = 25
# 3.3319698142401863
# Training error after  epoch : 31 here every batch size = 25
# 3.217111889302424
# Validation error after  epoch : 31 here batch size = 25
# 3.2889857679435535
# Training error after  epoch : 32 here every batch size = 25
# 3.163750249280656
# Validation error after  epoch : 32 here batch size = 25
# 3.248831512411831
# Training error after  epoch : 33 here every batch size = 25
# 3.1133025385794837
# Validation error after  epoch : 33 here batch size = 25
# 3.211757452688249
# Training error after  epoch : 34 here every batch size = 25
# 3.065644664941682
# Validation error after  epoch : 34 here batch size = 25
# 3.1772619371866733
# Training error after  epoch : 35 here every batch size = 25
# 3.020584036918913
# Validation error after  epoch : 35 here batch size = 25
# 3.1446715733637847
# Training error after  epoch : 36 here every batch size = 25
# 2.9778694089056383
# Validation error after  epoch : 36 here batch size = 25
# 3.114182311085795
# Training error after  epoch : 37 here every batch size = 25
# 2.9374059896577016
# Validation error after  epoch : 37 here batch size = 25
# 3.085307060966705
# Training error after  epoch : 38 here every batch size = 25
# 2.89902441842581
# Validation error after  epoch : 38 here batch size = 25
# 3.05793767177203
# Training error after  epoch : 39 here every batch size = 25
# 2.862642632856425
# Validation error after  epoch : 39 here batch size = 25
# 3.0320625470007703
# Training error after  epoch : 40 here every batch size = 25
# 2.828079199446081
# Validation error after  epoch : 40 here batch size = 25
# 3.007506368853475
# Training error after  epoch : 41 here every batch size = 25
# 2.7950450491866095
# Validation error after  epoch : 41 here batch size = 25
# 2.9841769872389783
# Training error after  epoch : 42 here every batch size = 25
# 2.7633617950219356
# Validation error after  epoch : 42 here batch size = 25
# 2.961968591531157
# Training error after  epoch : 43 here every batch size = 25
# 2.733086512311714
# Validation error after  epoch : 43 here batch size = 25
# 2.9403739654094987
# Training error after  epoch : 44 here every batch size = 25
# 2.7041012628645253
# Validation error after  epoch : 44 here batch size = 25
# 2.9195794087675324
# Training error after  epoch : 45 here every batch size = 25
# 2.676154791277035
# Validation error after  epoch : 45 here batch size = 25
# 2.89969037646011
# Training error after  epoch : 46 here every batch size = 25
# 2.6492281604641463
# Validation error after  epoch : 46 here batch size = 25
# 2.88063341533878
# Training error after  epoch : 47 here every batch size = 25
# 2.6232157997607257
# Validation error after  epoch : 47 here batch size = 25
# 2.8622547401295253
# Training error after  epoch : 48 here every batch size = 25
# 2.5981607032751297
# Validation error after  epoch : 48 here batch size = 25
# 2.844570324398853
# Training error after  epoch : 49 here every batch size = 25
# 2.574009814805396
# Validation error after  epoch : 49 here batch size = 25
# 2.827410171826596
# Training error after  epoch : 50 here every batch size = 25
# 2.550649131988554
# Validation error after  epoch : 50 here batch size = 25
# 2.8106744692553725
# Training error after  epoch : 51 here every batch size = 25
# 2.5280875737324475
# Validation error after  epoch : 51 here batch size = 25
# 2.7945421339476626
# Training error after  epoch : 52 here every batch size = 25
# 2.506175430777423
# Validation error after  epoch : 52 here batch size = 25
# 2.7786035748380447
# Training error after  epoch : 53 here every batch size = 25
# 2.484976613990338
# Validation error after  epoch : 53 here batch size = 25
# 2.763092344795348
# Training error after  epoch : 54 here every batch size = 25
# 2.464477211427359
# Validation error after  epoch : 54 here batch size = 25
# 2.7481479238485336
# Training error after  epoch : 55 here every batch size = 25
# 2.4445852511536854
# Validation error after  epoch : 55 here batch size = 25
# 2.733747058802541
# Training error after  epoch : 56 here every batch size = 25
# 2.4252871972192356
# Validation error after  epoch : 56 here batch size = 25
# 2.719866305484119
# Training error after  epoch : 57 here every batch size = 25
# 2.4066269774795583
# Validation error after  epoch : 57 here batch size = 25
# 2.706483383439214
# Training error after  epoch : 58 here every batch size = 25
# 2.3885112191871603
# Validation error after  epoch : 58 here batch size = 25
# 2.693580312688308
# Training error after  epoch : 59 here every batch size = 25
# 2.370992161859498
# Validation error after  epoch : 59 here batch size = 25
# 2.6811466088232065
# Training error after  epoch : 60 here every batch size = 25
# 2.3540274171426896
# Validation error after  epoch : 60 here batch size = 25
# 2.66908625479055
# Training error after  epoch : 61 here every batch size = 25
# 2.337629564669127
# Validation error after  epoch : 61 here batch size = 25
# 2.6573319409773966
# Training error after  epoch : 62 here every batch size = 25
# 2.3217322091526347
# Validation error after  epoch : 62 here batch size = 25
# 2.64607592505629
# Training error after  epoch : 63 here every batch size = 25
# 2.306338766397316
# Validation error after  epoch : 63 here batch size = 25
# 2.635330881084816
# Training error after  epoch : 64 here every batch size = 25
# 2.291418991383169
# Validation error after  epoch : 64 here batch size = 25
# 2.625098760862377
# Training error after  epoch : 65 here every batch size = 25
# 2.276970879038117
# Validation error after  epoch : 65 here batch size = 25
# 2.6153705550059168
# Training error after  epoch : 66 here every batch size = 25
# 2.263042199636339
# Validation error after  epoch : 66 here batch size = 25
# 2.6061339520346634
# Training error after  epoch : 67 here every batch size = 25
# 2.24961081854324
# Validation error after  epoch : 67 here batch size = 25
# 2.5973812949066972
# Training error after  epoch : 68 here every batch size = 25
# 2.2366189188194356
# Validation error after  epoch : 68 here batch size = 25
# 2.5891122874638484
# Training error after  epoch : 69 here every batch size = 25
# 2.2240625316578013
# Validation error after  epoch : 69 here batch size = 25
# 2.5813323166729014
# Training error after  epoch : 70 here every batch size = 25
# 2.21190869195779
# Validation error after  epoch : 70 here batch size = 25
# 2.574048700452187
# Training error after  epoch : 71 here every batch size = 25
# 2.2000390669835346
# Validation error after  epoch : 71 here batch size = 25
# 2.5672656085021845
# Training error after  epoch : 72 here every batch size = 25
# 2.1885185985794844
# Validation error after  epoch : 72 here batch size = 25
# 2.560914063568957
# Training error after  epoch : 73 here every batch size = 25
# 2.177284700198428
# Validation error after  epoch : 73 here batch size = 25
# 2.554978401092043
# Training error after  epoch : 74 here every batch size = 25
# 2.1663172109829207
# Validation error after  epoch : 74 here batch size = 25
# 2.549460634725973
# Training error after  epoch : 75 here every batch size = 25
# 2.1555528393722443
# Validation error after  epoch : 75 here batch size = 25
# 2.544280776559295
# Training error after  epoch : 76 here every batch size = 25
# 2.1450128517266336
# Validation error after  epoch : 76 here batch size = 25
# 2.539401401764685
# Training error after  epoch : 77 here every batch size = 25
# 2.1346438748093512
# Validation error after  epoch : 77 here batch size = 25
# 2.5348215441405144
# Training error after  epoch : 78 here every batch size = 25
# 2.124463783689101
# Validation error after  epoch : 78 here batch size = 25
# 2.5305453038502694
# Training error after  epoch : 79 here every batch size = 25
# 2.114534454650737
# Validation error after  epoch : 79 here batch size = 25
# 2.526549688328096
# Training error after  epoch : 80 here every batch size = 25
# 2.104805768110098
# Validation error after  epoch : 80 here batch size = 25
# 2.5228178916042987
# Training error after  epoch : 81 here every batch size = 25
# 2.0952915397616647
# Validation error after  epoch : 81 here batch size = 25
# 2.519337155952374
# Training error after  epoch : 82 here every batch size = 25
# 2.0860101081179567
# Validation error after  epoch : 82 here batch size = 25
# 2.516096271221954
# Training error after  epoch : 83 here every batch size = 25
# 2.076955328607565
# Validation error after  epoch : 83 here batch size = 25
# 2.513083248615144
# Training error after  epoch : 84 here every batch size = 25
# 2.0681209746702547
# Validation error after  epoch : 84 here batch size = 25
# 2.5102836622028737
# Training error after  epoch : 85 here every batch size = 25
# 2.0594766490402545
# Validation error after  epoch : 85 here batch size = 25
# 2.5076799546508965
# Training error after  epoch : 86 here every batch size = 25
# 2.0509856185507584
# Validation error after  epoch : 86 here batch size = 25
# 2.505251672302633
# Training error after  epoch : 87 here every batch size = 25
# 2.042636753625436
# Validation error after  epoch : 87 here batch size = 25
# 2.502976311421143
# Training error after  epoch : 88 here every batch size = 25
# 2.0344234254521485
# Validation error after  epoch : 88 here batch size = 25
# 2.5008303840180126
# Training error after  epoch : 89 here every batch size = 25
# 2.026407003655759
# Validation error after  epoch : 89 here batch size = 25
# 2.498790448073912
# Training error after  epoch : 90 here every batch size = 25
# 2.018549835693538
# Validation error after  epoch : 90 here batch size = 25
# 2.4968340486806384
# Training error after  epoch : 91 here every batch size = 25
# 2.0108615863268438
# Validation error after  epoch : 91 here batch size = 25
# 2.494940629794086
# Training error after  epoch : 92 here every batch size = 25
# 2.0033604956555755
# Validation error after  epoch : 92 here batch size = 25
# 2.4930924470717297
# Training error after  epoch : 93 here every batch size = 25
# 1.9959967615262972
# Validation error after  epoch : 93 here batch size = 25
# 2.4912753974722985
# Training error after  epoch : 94 here every batch size = 25
# 1.9887536859824442
# Validation error after  epoch : 94 here batch size = 25
# 2.4894795891070953
# Training error after  epoch : 95 here every batch size = 25
# 1.9816857978722642
# Validation error after  epoch : 95 here batch size = 25
# 2.4876667207982557
# Training error after  epoch : 96 here every batch size = 25
# 1.9747443766085295
# Validation error after  epoch : 96 here batch size = 25
# 2.4858119669742615
# Training error after  epoch : 97 here every batch size = 25
# 1.9679605051651208
# Validation error after  epoch : 97 here batch size = 25
# 2.4839354918239906
# Training error after  epoch : 98 here every batch size = 25
# 1.961333567796634
# Validation error after  epoch : 98 here batch size = 25
# 2.4819598844284187
# Training error after  epoch : 99 here every batch size = 25
# 1.9548487049722412
# Validation error after  epoch : 99 here batch size = 25
# 2.480015025485999
# Training error after  epoch : 100 here every batch size = 25
# 1.948502507565497
# Validation error after  epoch : 100 here batch size = 25
# 2.4781083940479935
# Training Error for 100th epoch for Trail Number : 3
# Training error after  epoch : 1 here every batch size = 25
# 16.23583162175841
# Validation error after  epoch : 1 here batch size = 25
# 15.414572635834157
# Training error after  epoch : 2 here every batch size = 25
# 13.919156804822832
# Validation error after  epoch : 2 here batch size = 25
# 13.333377471388928
# Training error after  epoch : 3 here every batch size = 25
# 12.226786539876294
# Validation error after  epoch : 3 here batch size = 25
# 11.799683537673177
# Training error after  epoch : 4 here every batch size = 25
# 10.821099170698506
# Validation error after  epoch : 4 here batch size = 25
# 10.513715827282226
# Training error after  epoch : 5 here every batch size = 25
# 9.645174463069694
# Validation error after  epoch : 5 here batch size = 25
# 9.436914961620856
# Training error after  epoch : 6 here every batch size = 25
# 8.672191349203962
# Validation error after  epoch : 6 here batch size = 25
# 8.548073418114603
# Training error after  epoch : 7 here every batch size = 25
# 7.854264293808642
# Validation error after  epoch : 7 here batch size = 25
# 7.8213336456264555
# Training error after  epoch : 8 here every batch size = 25
# 7.181197835113143
# Validation error after  epoch : 8 here batch size = 25
# 7.204483149618044
# Training error after  epoch : 9 here every batch size = 25
# 6.611651536472136
# Validation error after  epoch : 9 here batch size = 25
# 6.678746599576463
# Training error after  epoch : 10 here every batch size = 25
# 6.131637586040753
# Validation error after  epoch : 10 here batch size = 25
# 6.231292442834961
# Training error after  epoch : 11 here every batch size = 25
# 5.725445071533035
# Validation error after  epoch : 11 here batch size = 25
# 5.847895483793657
# Training error after  epoch : 12 here every batch size = 25
# 5.380378731067881
# Validation error after  epoch : 12 here batch size = 25
# 5.522502035633588
# Training error after  epoch : 13 here every batch size = 25
# 5.085112221168964
# Validation error after  epoch : 13 here batch size = 25
# 5.243642880607702
# Training error after  epoch : 14 here every batch size = 25
# 4.827493118773968
# Validation error after  epoch : 14 here batch size = 25
# 4.997379130090324
# Training error after  epoch : 15 here every batch size = 25
# 4.602385849812821
# Validation error after  epoch : 15 here batch size = 25
# 4.7824902622317715
# Training error after  epoch : 16 here every batch size = 25
# 4.405335489837554
# Validation error after  epoch : 16 here batch size = 25
# 4.594857725093582
# Training error after  epoch : 17 here every batch size = 25
# 4.231297384431185
# Validation error after  epoch : 17 here batch size = 25
# 4.428522713942394
# Training error after  epoch : 18 here every batch size = 25
# 4.078954967336354
# Validation error after  epoch : 18 here batch size = 25
# 4.280739553711578
# Training error after  epoch : 19 here every batch size = 25
# 3.9440887965719247
# Validation error after  epoch : 19 here batch size = 25
# 4.149082465458799
# Training error after  epoch : 20 here every batch size = 25
# 3.8241412869082447
# Validation error after  epoch : 20 here batch size = 25
# 4.0306671533374825
# Training error after  epoch : 21 here every batch size = 25
# 3.7172207878562844
# Validation error after  epoch : 21 here batch size = 25
# 3.9236015782249636
# Training error after  epoch : 22 here every batch size = 25
# 3.6208161108965
# Validation error after  epoch : 22 here batch size = 25
# 3.8271504876167164
# Training error after  epoch : 23 here every batch size = 25
# 3.5332144063979882
# Validation error after  epoch : 23 here batch size = 25
# 3.739930187201539
# Training error after  epoch : 24 here every batch size = 25
# 3.4527315449458156
# Validation error after  epoch : 24 here batch size = 25
# 3.6610511103067016
# Training error after  epoch : 25 here every batch size = 25
# 3.3788357768010377
# Validation error after  epoch : 25 here batch size = 25
# 3.588939834092114
# Training error after  epoch : 26 here every batch size = 25
# 3.310030690655369
# Validation error after  epoch : 26 here batch size = 25
# 3.522879319535642
# Training error after  epoch : 27 here every batch size = 25
# 3.2458118509755427
# Validation error after  epoch : 27 here batch size = 25
# 3.462437838667411
# Training error after  epoch : 28 here every batch size = 25
# 3.18570862228472
# Validation error after  epoch : 28 here batch size = 25
# 3.4075617219791554
# Training error after  epoch : 29 here every batch size = 25
# 3.1295855996846216
# Validation error after  epoch : 29 here batch size = 25
# 3.357320171072506
# Training error after  epoch : 30 here every batch size = 25
# 3.077306865909296
# Validation error after  epoch : 30 here batch size = 25
# 3.3113245482151115
# Training error after  epoch : 31 here every batch size = 25
# 3.0279414271751572
# Validation error after  epoch : 31 here batch size = 25
# 3.267813279634984
# Training error after  epoch : 32 here every batch size = 25
# 2.981993891812878
# Validation error after  epoch : 32 here batch size = 25
# 3.226639908443666
# Training error after  epoch : 33 here every batch size = 25
# 2.9393174578009145
# Validation error after  epoch : 33 here batch size = 25
# 3.1885519634142168
# Training error after  epoch : 34 here every batch size = 25
# 2.8997112859615783
# Validation error after  epoch : 34 here batch size = 25
# 3.1528379564041917
# Training error after  epoch : 35 here every batch size = 25
# 2.862822469045114
# Validation error after  epoch : 35 here batch size = 25
# 3.1193550595596933
# Training error after  epoch : 36 here every batch size = 25
# 2.8282500374546298
# Validation error after  epoch : 36 here batch size = 25
# 3.0880975566508795
# Training error after  epoch : 37 here every batch size = 25
# 2.795777741451251
# Validation error after  epoch : 37 here batch size = 25
# 3.0585156706842143
# Training error after  epoch : 38 here every batch size = 25
# 2.7651258942428067
# Validation error after  epoch : 38 here batch size = 25
# 3.0304140803070605
# Training error after  epoch : 39 here every batch size = 25
# 2.7360862860611017
# Validation error after  epoch : 39 here batch size = 25
# 3.00401078867137
# Training error after  epoch : 40 here every batch size = 25
# 2.708523592604413
# Validation error after  epoch : 40 here batch size = 25
# 2.979278492029707
# Training error after  epoch : 41 here every batch size = 25
# 2.6820930300623846
# Validation error after  epoch : 41 here batch size = 25
# 2.956104664888495
# Training error after  epoch : 42 here every batch size = 25
# 2.656918773235077
# Validation error after  epoch : 42 here batch size = 25
# 2.9343631914135404
# Training error after  epoch : 43 here every batch size = 25
# 2.632942706496172
# Validation error after  epoch : 43 here batch size = 25
# 2.9137597873533707
# Training error after  epoch : 44 here every batch size = 25
# 2.6101523862224947
# Validation error after  epoch : 44 here batch size = 25
# 2.894027500640516
# Training error after  epoch : 45 here every batch size = 25
# 2.588429468130297
# Validation error after  epoch : 45 here batch size = 25
# 2.874757010530094
# Training error after  epoch : 46 here every batch size = 25
# 2.56769831265216
# Validation error after  epoch : 46 here batch size = 25
# 2.856469145681635
# Training error after  epoch : 47 here every batch size = 25
# 2.5478379078217763
# Validation error after  epoch : 47 here batch size = 25
# 2.83886967663168
# Training error after  epoch : 48 here every batch size = 25
# 2.5287932459908133
# Validation error after  epoch : 48 here batch size = 25
# 2.822132080682668
# Training error after  epoch : 49 here every batch size = 25
# 2.510474338244213
# Validation error after  epoch : 49 here batch size = 25
# 2.8062548376332326
# Training error after  epoch : 50 here every batch size = 25
# 2.492927028096707
# Validation error after  epoch : 50 here batch size = 25
# 2.7911054605934633
# Training error after  epoch : 51 here every batch size = 25
# 2.4760863851019983
# Validation error after  epoch : 51 here batch size = 25
# 2.776676024537751
# Training error after  epoch : 52 here every batch size = 25
# 2.4599653471863925
# Validation error after  epoch : 52 here batch size = 25
# 2.762935308402424
# Training error after  epoch : 53 here every batch size = 25
# 2.444488005713707
# Validation error after  epoch : 53 here batch size = 25
# 2.7498497546698046
# Training error after  epoch : 54 here every batch size = 25
# 2.429546428030554
# Validation error after  epoch : 54 here batch size = 25
# 2.737390810439459
# Training error after  epoch : 55 here every batch size = 25
# 2.4150867340523523
# Validation error after  epoch : 55 here batch size = 25
# 2.7255292804299667
# Training error after  epoch : 56 here every batch size = 25
# 2.401136642140841
# Validation error after  epoch : 56 here batch size = 25
# 2.7142319628892584
# Training error after  epoch : 57 here every batch size = 25
# 2.3876244459343754
# Validation error after  epoch : 57 here batch size = 25
# 2.7034617359758637
# Training error after  epoch : 58 here every batch size = 25
# 2.3746244186918113
# Validation error after  epoch : 58 here batch size = 25
# 2.693179714063649
# Training error after  epoch : 59 here every batch size = 25
# 2.362075750596566
# Validation error after  epoch : 59 here batch size = 25
# 2.6833478275119536
# Training error after  epoch : 60 here every batch size = 25
# 2.349989431298587
# Validation error after  epoch : 60 here batch size = 25
# 2.6738184666455145
# Training error after  epoch : 61 here every batch size = 25
# 2.338338876784664
# Validation error after  epoch : 61 here batch size = 25
# 2.664380135773866
# Training error after  epoch : 62 here every batch size = 25
# 2.327096608284764
# Validation error after  epoch : 62 here batch size = 25
# 2.655315769452007
# Training error after  epoch : 63 here every batch size = 25
# 2.316226038661603
# Validation error after  epoch : 63 here batch size = 25
# 2.646612894124662
# Training error after  epoch : 64 here every batch size = 25
# 2.305641405254317
# Validation error after  epoch : 64 here batch size = 25
# 2.63826444571368
# Training error after  epoch : 65 here every batch size = 25
# 2.295363518509454
# Validation error after  epoch : 65 here batch size = 25
# 2.630265093364112
# Training error after  epoch : 66 here every batch size = 25
# 2.2853150824873625
# Validation error after  epoch : 66 here batch size = 25
# 2.6225575982712495
# Training error after  epoch : 67 here every batch size = 25
# 2.275514781482305
# Validation error after  epoch : 67 here batch size = 25
# 2.615124345699158
# Training error after  epoch : 68 here every batch size = 25
# 2.265950392474139
# Validation error after  epoch : 68 here batch size = 25
# 2.6079783775978256
# Training error after  epoch : 69 here every batch size = 25
# 2.256614698847493
# Validation error after  epoch : 69 here batch size = 25
# 2.6011418106061863
# Training error after  epoch : 70 here every batch size = 25
# 2.2474836421320417
# Validation error after  epoch : 70 here batch size = 25
# 2.594564292632481
# Training error after  epoch : 71 here every batch size = 25
# 2.2385812982707662
# Validation error after  epoch : 71 here batch size = 25
# 2.588213660571224
# Training error after  epoch : 72 here every batch size = 25
# 2.229863828517962
# Validation error after  epoch : 72 here batch size = 25
# 2.5821045379447765
# Training error after  epoch : 73 here every batch size = 25
# 2.221356292313554
# Validation error after  epoch : 73 here batch size = 25
# 2.5762418156930766
# Training error after  epoch : 74 here every batch size = 25
# 2.213022390176892
# Validation error after  epoch : 74 here batch size = 25
# 2.5706052012436555
# Training error after  epoch : 75 here every batch size = 25
# 2.2048559098723834
# Validation error after  epoch : 75 here batch size = 25
# 2.5651763221003487
# Training error after  epoch : 76 here every batch size = 25
# 2.1968975744630055
# Validation error after  epoch : 76 here batch size = 25
# 2.5599394914481697
# Training error after  epoch : 77 here every batch size = 25
# 2.189071976148491
# Validation error after  epoch : 77 here batch size = 25
# 2.5548815462346712
# Training error after  epoch : 78 here every batch size = 25
# 2.181410531662454
# Validation error after  epoch : 78 here batch size = 25
# 2.5499910521126394
# Training error after  epoch : 79 here every batch size = 25
# 2.173886639050941
# Validation error after  epoch : 79 here batch size = 25
# 2.545257542334329
# Training error after  epoch : 80 here every batch size = 25
# 2.16645032045543
# Validation error after  epoch : 80 here batch size = 25
# 2.5406712361574564
# Training error after  epoch : 81 here every batch size = 25
# 2.1591381113278723
# Validation error after  epoch : 81 here batch size = 25
# 2.5362175943120766
# Training error after  epoch : 82 here every batch size = 25
# 2.151973623717063
# Validation error after  epoch : 82 here batch size = 25
# 2.53180413587502
# Training error after  epoch : 83 here every batch size = 25
# 2.1449380128084705
# Validation error after  epoch : 83 here batch size = 25
# 2.5275149349427317
# Training error after  epoch : 84 here every batch size = 25
# 2.1380345283967417
# Validation error after  epoch : 84 here batch size = 25
# 2.5233431259665333
# Training error after  epoch : 85 here every batch size = 25
# 2.131223163293215
# Validation error after  epoch : 85 here batch size = 25
# 2.5192373043859395
# Training error after  epoch : 86 here every batch size = 25
# 2.124446455849305
# Validation error after  epoch : 86 here batch size = 25
# 2.5152134551466205
# Training error after  epoch : 87 here every batch size = 25
# 2.117715288803028
# Validation error after  epoch : 87 here batch size = 25
# 2.511286313835032
# Training error after  epoch : 88 here every batch size = 25
# 2.1110694281150164
# Validation error after  epoch : 88 here batch size = 25
# 2.5074501836997887
# Training error after  epoch : 89 here every batch size = 25
# 2.1045085646944597
# Validation error after  epoch : 89 here batch size = 25
# 2.50369973892778
# Training error after  epoch : 90 here every batch size = 25
# 2.0980068364401023
# Validation error after  epoch : 90 here batch size = 25
# 2.500030064632471
# Training error after  epoch : 91 here every batch size = 25
# 2.0915609891682703
# Validation error after  epoch : 91 here batch size = 25
# 2.496436612421029
# Training error after  epoch : 92 here every batch size = 25
# 2.0851949385591952
# Validation error after  epoch : 92 here batch size = 25
# 2.4929150820261143
# Training error after  epoch : 93 here every batch size = 25
# 2.078822580110155
# Validation error after  epoch : 93 here batch size = 25
# 2.4894612627081454
# Training error after  epoch : 94 here every batch size = 25
# 2.0724314888252082
# Validation error after  epoch : 94 here batch size = 25
# 2.4860463986951573
# Training error after  epoch : 95 here every batch size = 25
# 2.066128694531605
# Validation error after  epoch : 95 here batch size = 25
# 2.4826664091437682
# Training error after  epoch : 96 here every batch size = 25
# 2.0599125640944917
# Validation error after  epoch : 96 here batch size = 25
# 2.4793398879904736
# Training error after  epoch : 97 here every batch size = 25
# 2.0537411466273827
# Validation error after  epoch : 97 here batch size = 25
# 2.47598348039082
# Training error after  epoch : 98 here every batch size = 25
# 2.047562584633124
# Validation error after  epoch : 98 here batch size = 25
# 2.472666368573974
# Training error after  epoch : 99 here every batch size = 25
# 2.0413534557212514
# Validation error after  epoch : 99 here batch size = 25
# 2.469390506417892
# Training error after  epoch : 100 here every batch size = 25
# 2.035173802703808
# Validation error after  epoch : 100 here batch size = 25
# 2.4659502299392075
# Training Error for 100th epoch for Trail Number : 4
# Training error after  epoch : 1 here every batch size = 25
# 14.742302644881299
# Validation error after  epoch : 1 here batch size = 25
# 13.354913580865695
# Training error after  epoch : 2 here every batch size = 25
# 12.478236076305356
# Validation error after  epoch : 2 here batch size = 25
# 11.442224471855592
# Training error after  epoch : 3 here every batch size = 25
# 10.74154433888034
# Validation error after  epoch : 3 here batch size = 25
# 9.903555479065917
# Training error after  epoch : 4 here every batch size = 25
# 9.422077516374667
# Validation error after  epoch : 4 here batch size = 25
# 8.679957967085365
# Training error after  epoch : 5 here every batch size = 25
# 8.412269817047548
# Validation error after  epoch : 5 here batch size = 25
# 7.790831470751516
# Training error after  epoch : 6 here every batch size = 25
# 7.650616814739808
# Validation error after  epoch : 6 here batch size = 25
# 7.111199829429472
# Training error after  epoch : 7 here every batch size = 25
# 7.055910588325824
# Validation error after  epoch : 7 here batch size = 25
# 6.592452810504351
# Training error after  epoch : 8 here every batch size = 25
# 6.576095589372552
# Validation error after  epoch : 8 here batch size = 25
# 6.18084759905797
# Training error after  epoch : 9 here every batch size = 25
# 6.1753091163642555
# Validation error after  epoch : 9 here batch size = 25
# 5.846302724392302
# Training error after  epoch : 10 here every batch size = 25
# 5.836136106726606
# Validation error after  epoch : 10 here batch size = 25
# 5.570735059874182
# Training error after  epoch : 11 here every batch size = 25
# 5.5422968871926335
# Validation error after  epoch : 11 here batch size = 25
# 5.339719604638085
# Training error after  epoch : 12 here every batch size = 25
# 5.282169018793752
# Validation error after  epoch : 12 here batch size = 25
# 5.13803481370878
# ...
# 2.70705039930771
# Validation error after  epoch : 50 here batch size = 25
# 3.120132526694302
# Training error after  epoch : 51 here every batch size = 25
# 2.6848521324755272
# Validation error after  epoch : 51 here batch size = 25
# 3.105896143318501
# Training error after  epoch : 52 here every batch size = 25
# 2.6635210715372417
# Validation error after  epoch : 52 here batch size = 25
# 3.092395043235963
# Training error after  epoch : 53 here every batch size = 25
# 2.643049749978679
# Validation error after  epoch : 53 here batch size = 25
# 3.079553711495069
# Training error after  epoch : 54 here every batch size = 25
# 2.6234654055756477
# Validation error after  epoch : 54 here batch size = 25
# 3.067125750144173
# Training error after  epoch : 55 here every batch size = 25
# 2.6045917339799374
# Validation error after  epoch : 55 here batch size = 25
# 3.055285919174172
# Training error after  epoch : 56 here every batch size = 25
# 2.5863130877264116
# Validation error after  epoch : 56 here batch size = 25
# 3.0439727950371673
# Training error after  epoch : 57 here every batch size = 25
# 2.5686910013275646
# Validation error after  epoch : 57 here batch size = 25
# 3.0329822240702833
# Training error after  epoch : 58 here every batch size = 25
# 2.5516912614614538
# Validation error after  epoch : 58 here batch size = 25
# 3.0224509472068473
# Training error after  epoch : 59 here every batch size = 25
# 2.535303443281971
# Validation error after  epoch : 59 here batch size = 25
# 3.0123560548046724
# Training error after  epoch : 60 here every batch size = 25
# 2.5194357684332385
# Validation error after  epoch : 60 here batch size = 25
# 3.0025073237112325
# Training error after  epoch : 61 here every batch size = 25
# 2.5041274885669234
# Validation error after  epoch : 61 here batch size = 25
# 2.9930002112140177
# Training error after  epoch : 62 here every batch size = 25
# 2.4892026043861195
# Validation error after  epoch : 62 here batch size = 25
# 2.983907362021719
# Training error after  epoch : 63 here every batch size = 25
# 2.474660649134824
# Validation error after  epoch : 63 here batch size = 25
# 2.9752098224094867
# Training error after  epoch : 64 here every batch size = 25
# 2.4606151541609558
# Validation error after  epoch : 64 here batch size = 25
# 2.9669006002224876
# Training error after  epoch : 65 here every batch size = 25
# 2.4469029812618497
# Validation error after  epoch : 65 here batch size = 25
# 2.958891659740788
# Training error after  epoch : 66 here every batch size = 25
# 2.4335415666593923
# Validation error after  epoch : 66 here batch size = 25
# 2.9511133663734608
# Training error after  epoch : 67 here every batch size = 25
# 2.420680262537687
# Validation error after  epoch : 67 here batch size = 25
# 2.9435999754718263
# Training error after  epoch : 68 here every batch size = 25
# 2.4082724940039792
# Validation error after  epoch : 68 here batch size = 25
# 2.9362314313823528
# Training error after  epoch : 69 here every batch size = 25
# 2.3962941561307427
# Validation error after  epoch : 69 here batch size = 25
# 2.92922279388588
# Training error after  epoch : 70 here every batch size = 25
# 2.384731196099853
# Validation error after  epoch : 70 here batch size = 25
# 2.9225537348950774
# Training error after  epoch : 71 here every batch size = 25
# 2.3735719620796036
# Validation error after  epoch : 71 here batch size = 25
# 2.916204685097059
# Training error after  epoch : 72 here every batch size = 25
# 2.362775193791857
# Validation error after  epoch : 72 here batch size = 25
# 2.910156468421235
# Training error after  epoch : 73 here every batch size = 25
# 2.3523131022343065
# Validation error after  epoch : 73 here batch size = 25
# 2.9043886914716825
# Training error after  epoch : 74 here every batch size = 25
# 2.3421813516626373
# Validation error after  epoch : 74 here batch size = 25
# 2.8987815076092796
# Training error after  epoch : 75 here every batch size = 25
# 2.3323575814034383
# Validation error after  epoch : 75 here batch size = 25
# 2.892951786311313
# Training error after  epoch : 76 here every batch size = 25
# 2.3227751653745097
# Validation error after  epoch : 76 here batch size = 25
# 2.887052206849916
# Training error after  epoch : 77 here every batch size = 25
# 2.313382847768765
# Validation error after  epoch : 77 here batch size = 25
# 2.8813340646961807
# Training error after  epoch : 78 here every batch size = 25
# 2.304232078920095
# Validation error after  epoch : 78 here batch size = 25
# 2.875778537035094
# Training error after  epoch : 79 here every batch size = 25
# 2.2952598222292293
# Validation error after  epoch : 79 here batch size = 25
# 2.870370787735209
# Training error after  epoch : 80 here every batch size = 25
# 2.286448468481273
# Validation error after  epoch : 80 here batch size = 25
# 2.8651000676135836
# Training error after  epoch : 81 here every batch size = 25
# 2.277850921929145
# Validation error after  epoch : 81 here batch size = 25
# 2.859959522292329
# Training error after  epoch : 82 here every batch size = 25
# 2.2694441011052224
# Validation error after  epoch : 82 here batch size = 25
# 2.8549458378751003
# Training error after  epoch : 83 here every batch size = 25
# 2.26116718053224
# Validation error after  epoch : 83 here batch size = 25
# 2.8499906156198596
# Training error after  epoch : 84 here every batch size = 25
# 2.25305656761899
# Validation error after  epoch : 84 here batch size = 25
# 2.8449639473925767
# Training error after  epoch : 85 here every batch size = 25
# 2.2451310050649935
# Validation error after  epoch : 85 here batch size = 25
# 2.840064702144062
# Training error after  epoch : 86 here every batch size = 25
# 2.2373855710781685
# Validation error after  epoch : 86 here batch size = 25
# 2.8352009978558432
# Training error after  epoch : 87 here every batch size = 25
# 2.229769126517311
# Validation error after  epoch : 87 here batch size = 25
# 2.830410705602529
# Training error after  epoch : 88 here every batch size = 25
# 2.222287829663174
# Validation error after  epoch : 88 here batch size = 25
# 2.8257639052505543
# Training error after  epoch : 89 here every batch size = 25
# 2.2149420674748113
# Validation error after  epoch : 89 here batch size = 25
# 2.821264433760084
# Training error after  epoch : 90 here every batch size = 25
# 2.2076617947860298
# Validation error after  epoch : 90 here batch size = 25
# 2.8169154480833116
# Training error after  epoch : 91 here every batch size = 25
# 2.2004923705413857
# Validation error after  epoch : 91 here batch size = 25
# 2.812719380074964
# Training error after  epoch : 92 here every batch size = 25
# 2.193474436586178
# Validation error after  epoch : 92 here batch size = 25
# 2.808677661239244
# Training error after  epoch : 93 here every batch size = 25
# 2.186602039908552
# Validation error after  epoch : 93 here batch size = 25
# 2.8047902057592196
# Training error after  epoch : 94 here every batch size = 25
# 2.1798244002538656
# Validation error after  epoch : 94 here batch size = 25
# 2.801054821679055
# Training error after  epoch : 95 here every batch size = 25
# 2.1731648034222633
# Validation error after  epoch : 95 here batch size = 25
# 2.7974668306244985
# Training error after  epoch : 96 here every batch size = 25
# 2.166587123635284
# Validation error after  epoch : 96 here batch size = 25
# 2.7940191458992545
# Training error after  epoch : 97 here every batch size = 25
# 2.1600888506023264
# Validation error after  epoch : 97 here batch size = 25
# 2.7907028838287373
# Training error after  epoch : 98 here every batch size = 25
# 2.1536173301427857
# Validation error after  epoch : 98 here batch size = 25
# 2.787422411576963
# Training error after  epoch : 99 here every batch size = 25
# 2.1471048633640453
# Validation error after  epoch : 99 here batch size = 25
# 2.784159587362071
# Training error after  epoch : 100 here every batch size = 25
# 2.140698402927523
# Validation error after  epoch : 100 here batch size = 25
# 2.7810006472707194
#
#
# Final Training Errors after 5 trails and 100 Epocs :
# [15.035148477290713, 12.509590973247297, 10.977932048299397, 9.719523076430104, 8.665632161595468, 7.809166389523898, 7.1161411505915115, 6.569285030050049, 6.122572354432831, 5.750887771739003, 5.436156946093576, 5.166022185992461, 4.935279869863837, 4.736297638998033, 4.563400108376681, 4.412046098989488, 4.277767575803647, 4.158904555040648, 4.054342082927707, 3.9612580493867915, 3.87788874805065, 3.802063738297518, 3.732303009708832, 3.667084704812948, 3.606444703138594, 3.549717371759913, 3.496006825589465, 3.4452633226779, 3.3976074227549105, 3.35242821600751, 3.309594802942415, 3.26895473541184, 3.2300906311302224, 3.1930947707009714, 3.157968455502616, 3.1243162266466635, 3.091910186822356, 3.0605161233728198, 3.0302500913151356, 3.001330606444125, 2.973666934705742, 2.9469724717736967, 2.921314547348916, 2.8963560455616375, 2.8721428449323705, 2.8486628241056104, 2.825975693685249, 2.803669371749432, 2.781812462343105, 2.7606612731895397, 2.7401625912026515, 2.7203335227665355, 2.7011786028934526, 2.682567987946335, 2.664470604361364, 2.646963533600637, 2.6299901683520637, 2.6135289257746916, 2.597560293711018, 2.582049326082986, 2.566931991528083, 2.552182628404455, 2.537710118550472, 2.5235751870021152, 2.5097341239420627, 2.4962667861813896, 2.483139691021422, 2.4704162460885115, 2.458046086167298, 2.4458964144321107, 2.4341496534867724, 2.42280137053518, 2.411796370808178, 2.4010890871215604, 2.3907231885125553, 2.380696032958309, 2.3709584038755547, 2.3613857081964915, 2.3520024932348025, 2.3429015673516616, 2.334044170801763, 2.325365029801194, 2.316762525882853, 2.308363922802357, 2.3002052603629695, 2.2922370613979504, 2.2844647370358713, 2.2768111226075307, 2.2693558241587866, 2.2620319345827453, 2.25485563126031, 2.2477870910209146, 2.240825235419017, 2.234028758596041, 2.227402985360045, 2.220953403885846, 2.2146768830657977, 2.2085247129648806, 2.2025227778579537, 2.196685676794994, 16.604653421333307, 14.483851386409208, 12.658947958663243, 11.145503488396376, 9.917926456276899, 8.902804646501902, 8.071518304935216, 7.3871690333412126, 6.82188433867916, 6.348734752031685, 5.957771882581695, 5.626322626928118, 5.342097300724044, 5.097115162942952, 4.883042392864356, 4.692513075480668, 4.521225999905283, 4.368213718949932, 4.2306183558977954, 4.105109868822413, 3.9910572825709774, 3.8865598974073565, 3.7897595384175533, 3.700072633970548, 3.616600189032402, 3.538893253061529, 3.4653858807053797, 3.3968309340098695, 3.3330371512891266, 3.273105702565148, 3.217111889302424, 3.163750249280656, 3.1133025385794837, 3.065644664941682, 3.020584036918913, 2.9778694089056383, 2.9374059896577016, 2.89902441842581, 2.862642632856425, 2.828079199446081, 2.7950450491866095, 2.7633617950219356, 2.733086512311714, 2.7041012628645253, 2.676154791277035, 2.6492281604641463, 2.6232157997607257, 2.5981607032751297, 2.574009814805396, 2.550649131988554, 2.5280875737324475, 2.506175430777423, 2.484976613990338, 2.464477211427359, 2.4445852511536854, 2.4252871972192356, 2.4066269774795583, 2.3885112191871603, 2.370992161859498, 2.3540274171426896, 2.337629564669127, 2.3217322091526347, 2.306338766397316, 2.291418991383169, 2.276970879038117, 2.263042199636339, 2.24961081854324, 2.2366189188194356, 2.2240625316578013, 2.21190869195779, 2.2000390669835346, 2.1885185985794844, 2.177284700198428, 2.1663172109829207, 2.1555528393722443, 2.1450128517266336, 2.1346438748093512, 2.124463783689101, 2.114534454650737, 2.104805768110098, 2.0952915397616647, 2.0860101081179567, 2.076955328607565, 2.0681209746702547, 2.0594766490402545, 2.0509856185507584, 2.042636753625436, 2.0344234254521485, 2.026407003655759, 2.018549835693538, 2.0108615863268438, 2.0033604956555755, 1.9959967615262972, 1.9887536859824442, 1.9816857978722642, 1.9747443766085295, 1.9679605051651208, 1.961333567796634, 1.9548487049722412, 1.948502507565497, 16.23583162175841, 13.919156804822832, 12.226786539876294, 10.821099170698506, 9.645174463069694, 8.672191349203962,  ...
#
#
# Final Validation Errors after 5 trails and 100 Epocs :
# [13.13189156488082, 11.172910178083995, 9.794883399075434, 8.733528150885483, 7.906000090238052, 7.24362216216624, 6.740421495869243, 6.3537766753021545, 6.03328080824811, 5.760416267893245, 5.526327412408725, 5.320306189115524, 5.139952524213031, 4.981741984105906, 4.844302757963496, 4.7257190073262585, 4.619341671105278, 4.5248561264113825, 4.440494324181205, 4.363342670276551, 4.29221135030702, 4.2260904092552405, 4.165062607262018, 4.1083875894205, 4.056104796298605, 4.007908751191278, 3.963106043390033, 3.9210480661622342, 3.881244236869778, 3.843394675248945, 3.807811189987602, 3.7742484515367196, 3.742447512615781, 3.712420403737955, 3.6840358332834815, 3.6570474242935744, 3.631371215578394, 3.606749586599628, 3.583550815432626, 3.5614102772035867, 3.539955822433127, 3.5194967339008567, 3.4998684968397753, 3.4808061407992286, 3.4623219844667505, 3.4445449256273077, 3.427498121631924, 3.4111470113002826, 3.3952825128356072, 3.380072972787017, 3.3655630852291405, 3.351515570707935, 3.337834871557382, 3.324513223668027, 3.311850322329742, 3.2998923057479828, 3.2885859310442758, 3.2778741334647474, 3.267567387139553, 3.257549644762139, 3.247904312824978, 3.238579296886148, 3.229647884624518, 3.2210875464932784, 3.212877236932726, 3.2047251719900727, 3.196531811953491, 3.1884981124280807, 3.180740175915766, 3.1732383909619957, 3.1659771142833035, 3.158944756810038, 3.1519073196674956, 3.1449293771521183, 3.138112103410458, 3.131407214805385, 3.1247505368174218, 3.1182704847445324, 3.1119855800098235, 3.1058808288368063, 3.0998210169993103, 3.093315950508406, 3.086951269579115, 3.0807151558861854, 3.074597000830597, 3.068587488415953, 3.0625926966759964, 3.056646468199584, 3.0507905273537723, 3.045020103171952, 3.0393318948733428, 3.0337242861933453, 3.0281974175368407, 3.0227530792573334, 3.0173944836990616, 3.0121260369886445, 3.006953240109234, 3.0018827827623977, 2.9969227521236443, 2.992082727962585, 15.146409138754342, 13.115983811018323, 11.51045177897779, 10.170462244669725, 9.048410989934782, 8.133277103842609, 7.375685066697888, 6.769128919644472, 6.280949789387007, 5.882377391644492, 5.554890731057574, 5.28213889009394, 5.045703084847554, 4.837475668550588, 4.657077543189672, 4.494775006824133, 4.349563247844168, 4.217809414747726, 4.101705568152371, 3.9975013610739847, 3.9025343828406505, 3.815672703951351, 3.737010613898635, 3.6651968289203256, 3.599124987269755, 3.537736505755431, 3.4805742505550405, 3.427651804124429, 3.3779244322481192, 3.3319698142401863, 3.2889857679435535, 3.248831512411831, 3.211757452688249, 3.1772619371866733, 3.1446715733637847, 3.114182311085795, 3.085307060966705, 3.05793767177203, 3.0320625470007703, 3.007506368853475, 2.9841769872389783, 2.961968591531157, 2.9403739654094987, 2.9195794087675324, 2.89969037646011, 2.88063341533878, 2.8622547401295253, 2.844570324398853, 2.827410171826596, 2.8106744692553725, 2.7945421339476626, 2.7786035748380447, 2.763092344795348, 2.7481479238485336, 2.733747058802541, 2.719866305484119, 2.706483383439214, 2.693580312688308, 2.6811466088232065, 2.66908625479055, 2.6573319409773966, 2.64607592505629, 2.635330881084816, 2.625098760862377, 2.6153705550059168, 2.6061339520346634, 2.5973812949066972, 2.5891122874638484, 2.5813323166729014, 2.574048700452187, 2.5672656085021845, 2.560914063568957, 2.554978401092043, 2.549460634725973, 2.544280776559295, 2.539401401764685, 2.5348215441405144, 2.5305453038502694, 2.526549688328096, 2.5228178916042987, 2.519337155952374, 2.516096271221954, 2.513083248615144, 2.5102836622028737, 2.5076799546508965, 2.505251672302633, 2.502976311421143, 2.5008303840180126, 2.498790448073912, 2.4968340486806384, 2.494940629794086, 2.4930924470717297, 2.4912753974722985, 2.4894795891070953, 2.4876667207982557, 2.4858119669742615, 2.4839354918239906, 2.4819598844284187, 2.480015025485999, 2.4781083940479935, 15.414572635834157, 13.333377471388928, 11.799683537673177, 10.513715827282226, 9.436914961620856, 8.548073418114603, 7.82 ...
#
#
# Plots are started to Generate In Figures Folder :
# Plots are Generated Successfully In Figures folder

# %%
err, o_softmax = forward_pass(X[4000: ], W, V, Y[4000:])
correct_predictions = 0
for o, y in zip(o_softmax, Y[4000:]):
    if np.argmax(o) == np.argmax(y):
        correct_predictions += 1
print(correct_predictions)
# Out:
# 779

# %%
print(f'Testing Accuracy = {cnt / 1000 * 100}%')
# Out:
# Testing Accuracy = 77.9%

# %% [markdown]
# **Observations:** Along with each epoch, training error and validation error were reducing. Which suggests the MLP worked fine. Also the network achieves the accuracy of 78%
