# %% [markdown]
# ##  Lab 3(a) - Implementation of Multi layer perceptron from scratch
# ##  Weightage - 2.4%
#
# Maximum Points in the Lab: 90
#
# ---
# Important points to remember :
#
#
# 1.  Observations for the experiments should be explained.
# 2. All the code should be submitted in the form of a single Jupyter notebook itself.
# 3. Points for each sub-section are mentioned in the appropriate question.
# 4. Make sure to begin early as a few experiments may consume more time to run.
# 5. You can use Google colab to run in jupyter notebook (https://colab.research.google.com/) How to load data in Google Colab ?(https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92)
# 6. The lab must be submitted on Google classroom. The code as well as the accompanying observations should be made part of the python notebook.
# 7. **Code Readability** is very important. Hence use self explanatory variable names and add comments to describe your approach wherever necessary.
# 8. You are expected to submit your **detailed inferences** and not just an error free code.
# 9. The lab is due on **March 20th 11.59pm**.
# 10. The lab should be completed **individually**. Students are expected to follow the **honor code** of the class.
#
# For any doubts regarding lab please mail to 2018csm1011@iitrpr.ac.in
#
#
# Below is the multi layer perceptron architechture used for implementation. Notations of the neural network are mentioned below :

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive/Colab\ Notebooks/lab3
# Out:
# /content/drive/My Drive/Colab Notebooks/lab3

# %% [markdown]
# ![MLP implementation diagram](pictures/mlp.png)

# %% [markdown]
# ## Implementation details :
#
# 1) In this lab you will be using MLP for classifying MNIST digits. a. Let us consider a MLP network with H hidden units, O outputs, and
# inputs of size D.
#
# 2) According to above diagram dimensions of network will be :
# ```
#  W - H * D+1   -- Weights from Input layer to Hidden layer
#  V - K * H+1   -- Weights from Hidden layer to Output layer
#  X - N * D+1   -- Weights of Input data
#  Y - N * K     -- Weights of Output label data
#  Z - H+1 * 1   -- Hidden layer Weights
#  O - K * 1     -- Output layer weights
# ```
# 3) Please note that +1 in above notations is to indicate bias term.
#
# 4) tanh is used as the activation function.
#
# 5) During forward pass will be :
#
# $\mathbf{z}=\tanh (\mathbf{W} \mathbf{x})$
#
# and $O_{i}=\frac{\exp v_{i}^{T} z}{\sum_{k=1}^{K} \exp v_{k}^{T} z}$
#
# Overall loss function will be :
#
# Total loss = $-\sum_{n=1}^{N} \sum_{i=1}^{K} y_{n i} \log O_{n i}$

# %% [markdown]
# 6) The dataset is included in zip file ("data.txt" and "label.txt"). Number of hidden layer units to be 500, learning rate is set to be 0.01.
#
# 7) Inorder to update the weights during back propogation we will modified version of stochastic gradient descent, where instead of updating weights after each data point, the updates are made once with batch of input data, Let batch size = 25. Number of epochs = 100.
#
# 8) Divide the data into train, validation, and test splits using a preset ratio. Please define the ratio you are using.
#
# 9) Please plot the below :
#
#     i)  Training error, Validation error Vs epochs [average over 5 runs.]
#
#     ii) Mean Training error Vs epochs [average over 5 runs.]
#
#     iii)  Mean Validation error Vs epochs [average over 5 runs.]
#
#     iv) Variance Training error Vs epochs [average over 5 runs.]
#
#      v)  Variance validation error Vs epochs [average over 5 runs.]

# %% [markdown]
# # Note :
#
# 1) All weight update equations during back propogation should be done using $\textbf{Matrix operations}$ only (not for loops).
#
#  For example :
#
# ![MLP implementation diagram](pictures/equation.png)

# %% [markdown]
# # Maximum points : 90 points.
#
# 1) Derive the weight update equation for W in form of Matrix operations similar to V matrix operations defined above.(write in the jupyter notebook itself using Latex or image) - 10 pts
#
# 2) Splitting train, validation and test using preset ratio - 5 pts
#
# 3) Random weights assign to W,V values -  5 pts.
#
# 4) During Forward pass :
#
#        updating Z values - 5 pts.
#
#        updating O values - 5 pts.
#
#        Applying softmax values - 5pts.
#
#        Calculating error values - 5pts.
#
# 5) During backward pass : ( only matrix operations allowed)
#
#        Gradient between hidden to output - 10 pts.
#
#        Gradient betweem input to hidden - 15 pts.
#
# 6) Using batch size = 25 to update weights - 5 pts.
#
# 7) averaging over 5 runs - 5 pts.
#
# 8) Please plot the below : - 10pts.
#
#     i)  Training error, Validation error Vs epochs [average over 5 runs.]
#
#     ii) Mean Training error Vs epochs [average over 5 runs.]
#
#     iii)  Mean Validation error Vs epochs [average over 5 runs.]
#
#     iv) Variance Training error Vs epochs [average over 5 runs.]
#
#      v)  Variance validation error Vs epochs [average over 5 runs.]
#
# 9) Discuss the observations from above plots. - 5pts.

# %% [markdown]
# ## Update Equation of W
# ---
# ![W_upd.png](pictures/W_upd.png)
#
# Here, dimensions of
# ```
# W - H * D+1
# X - N * D+1
# O - N * K
# Y - N * K
# V - K * H
# z - 1 * H (Mean of z's)
# 1 - 1 * H (Matrix of ones)
# ```
# o represents Hadamard product.
#
# //In case the image above is not visible please look in the pictures directory.//

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

####################################################################################
# Derivative of weights as defined in Lab3.a	####################################
####################################################################################
####################################################################################

# Dimension of all the Matrices Used
# W - H * D+1   -- Weights from Input layer to Hidden layer
# V - K * H+1   -- Weights from Hidden layer to Output layer
# X - N * D+1   -- Weights of Input data
# Y - N * K     -- Weights of Output label data
# Z - H+1 * 1   -- Hidden layer Weights
# O - K * 1     -- Output layer weights


# Function to read data and store it in form of 2D array
def read_data(file_name) :
    data = np.loadtxt(file_name, delimiter=',')
    return data


# Implementation of Forward pass function
def forward_pass(data_points,W,V,Y) :
    # use compute_Z_values, compute_O_values, compute_softmax, calculate_error to compute error, O_softmax
    # During forward pass compute Z values, O_values, O_softmax, error
    # Insert code here
    z = compute_Z_values(W, data_points)
    o = compute_O_values(V, z)
    O_softmax = compute_softmax(o)
    error = calculate_error(O_softmax, Y)
    #return the error, O_softmax
    return error,O_softmax


# Implementation of Cross Entropy Error Function takes as input O_softmax, Y
def calculate_error(predictions, targets, epsilon=1e-10):
    # Caculate cross entropy error between output of softmax (predictions) , actual values (targets)
    #Insert code here
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    cross_entropy_error = - np.sum(targets * np.log(predictions)) / predictions.shape[0]
    #returns cross entropy error
    return cross_entropy_error


# Implementation of Softmax Error Function takes as input O

def compute_softmax(output_matrix) :
    # return output_matrix after apply softmax function ( hint: use np.exp function ) 25*10
    y_length = 10
    #Insert code here
    for i in range(len(output_matrix)):
        output_matrix[i] = np.exp(output_matrix[i] - np.max(output_matrix[i]))
        output_matrix[i] /= np.sum(output_matrix[i])
    return output_matrix


# Implementation of Backward pass using Backpropagation Algorithm to calculate V_new, W_new, bias_v
def backward_pass(O_softmax,Y,V,Z,W,X,bias_z):
    # use gradient_hidden_to_output, gradient_input_to_hidden functions to compute V_new, bias_v, W_new 
    #Insert code here
    V_new, bias_v = gradient_hidden_to_output(O_softmax, Y, Z, bias_z)
    W_new = gradient_input_to_hidden(O_softmax, Y, V, Z, X)
    #returns V_new, W_new, bias_v
    return  W_new,V_new,bias_v


#Implementation of Graident back propogation from Hidden to Input Layer
def gradient_hidden_to_output(O_softmax,Y,Z,bias_z) :
    # function to update V values using backpropogation using matrix operations.
    #Insert code here
    Z_ = initilaise_weights(Z.T).T
    final_result_matrix = np.dot((O_softmax - Y).T, Z_.T)
    bias_v = final_result_matrix.T[final_result_matrix.shape[1]-1]
    final_result_matrix = final_result_matrix[:, :final_result_matrix.shape[1]-1]
    bias_v = bias_v.reshape((bias_v.shape[0], 1))
    return final_result_matrix,bias_v

#Implementation of Graident back propogation from Input to Hidden Layer
def gradient_input_to_hidden(O_softmax,Y,V,Z,X) :
    # function to update W values using backpropogation using only matrix operations.
    #Insert code here
    z_ = np.ones(Z.shape) - Z*Z
    z_ = np.mean(z_, axis=1)
    V = V[:, :V.shape[1]-1]
    result_matrix = np.dot(np.dot(X.T,O_softmax - Y), V*z_) # ---- Need to understand ----#
    # returns updated W values
    return result_matrix.T



# Function to calculate Z values during forward pass
def compute_Z_values(weights,data_points) :
    # function to update Z during forward pass using matrix operations.
    #Insert code here
    z_values = np.dot(weights, data_points.T)
    # print(z_values, np.max(weights))
    z_values = np.tanh(z_values)
    # assert(1 == 0)
    #return calculated z_values
    return z_values


# Function to Calculate output matrix during forward pass
def compute_O_values(weights,z_values) :
    # function to update O during forward pass using matrix operations.
    #Insert code here
    o_values = np.dot(weights, initilaise_weights(z_values.T).T)
    #return calculated o_values
    return o_values.T



# Function to Intialise weights with bias term
def initilaise_weights(data) :
    # function to append bias term.
    # insert code here
    final_data = np.concatenate((data, np.ones((data.shape[0], 1))), axis=1)
    return final_data



# To intiliase random weights to Matrices such as W, V
def random_weights(number_of_rows,number_of_columns) :
    # Function to assign random weights to W, V
    #Insert code here 
    new_data = np.random.randn(number_of_rows, number_of_columns) / np.sqrt(number_of_columns)
    # return random weights with number_of_rows * number_of_columns
    return new_data


# To divide the data into test train data
def train_test_split(X,Y,fraction) :
    # Function to divide train, validation and test data based on fraction. let fraction = 0.8 then train = 0.75, validation= 0.05 and test = 0.2 
    #Insert code here
    shuf_indices = np.random.permutation(X.shape[0])
    val_samples = int(fraction * (1 - fraction) * len(shuf_indices))
    validation_data_x = X[shuf_indices[:val_samples]]
    validation_data_y = Y[shuf_indices[:val_samples]]
    train_samples = int(fraction * len(shuf_indices))
    data_train_x = X[shuf_indices[val_samples: train_samples]]
    data_train_y = Y[shuf_indices[val_samples: train_samples]]
    test_data_x = X[shuf_indices[train_samples:]]
    test_data_y = Y[shuf_indices[train_samples:]]
    # return data_train_x,data_train_y,validation_data_x,validation_data_y,test_data_x,test_data_y
    return data_train_x,data_train_y,validation_data_x,validation_data_y,test_data_x,test_data_y


# Shuffle in same order for X,Y
def shuffle(a, b, seed):
   # to Shuffle in same order for X,Y based on seed
   #Insert code here10000
    np.random.seed(seed)
    shuf_indices = np.random.permutation(a.shape[0])
    a = a[shuf_indices]
    b = b[shuf_indices]
   # return shuffled values a,b in same order
    return a,b


if __name__ == "__main__" :
    data = read_data("data.txt")
    Y = read_data("label.txt")
    X = initilaise_weights(data)
    W = random_weights(500,401)
    V = random_weights(10,501)
    Z = compute_Z_values(W,X[:25,:])
    O = compute_O_values(V,Z)
    bias_z = np.empty(shape=(25, 1))
    bias_z.fill(1.0)
    i=0
    learning_rate = 0.01
    train_test_fraction  = 0.8
    train_validation_split = 0.2
    train_data_x,train_data_y,validation_data_x,validation_data_y,test_data_x,test_data_y =train_test_split(X,Y,train_test_fraction)
    number_of_epocs=100
    train_error_epoch = []*(5*number_of_epocs)
    #X = train_data_x
    #Y = train_data_y
    #Dividing the data into training data and test data into 0.8 ratio same ration for train and validation data,values below correspond to 0.8 ratio
    train_data_len = 3200
    validation_data_len = 800
    test_data_len =1000
    validation_error_epoch = [] * (5*number_of_epocs)
    # Running for 5 trails using 100 Epocs and Batch size = 25
    batch_size = 25
    print("Started calculating Training error in 5 Trails for each epoch with Batch size = 25 ")
    print("Started calculating Validation error in 5 Trails for each epoch with Batch size = 25 ")
    # Different trails are performed for 5 times.
    # 5 different trails
    trails = 5
    for k in range(trails) :
        W = random_weights(500, 401)
        V = random_weights(10, 501)
        error_train=0
        error_validation = 0
        # Randomising the data
        seed = random.randint(10000,10000000)
        X,Y = shuffle(X,Y,seed)
        print("Training Error for 100th epoch for Trail Number : "+str(k+1))
        for j in range(number_of_epocs) :
            i=0
            error_train = 0.0
            error_validation = 0.0
            count = 0
            #X,Y = shuffle(X,Y,12345)
            while i < (train_data_len)  :
                i1=i
                # Batch size is 25
                i= i+25
                error,O_softmax=forward_pass(X[i1:i, :], W, V, Y[i1:i, :])
                W_new,V_new,bias_v=backward_pass(O_softmax,Y[i1:i,:],V,Z,W,X[i1:i,:],bias_z)
                #print(W_new.shape)
                W = W - (learning_rate/25)*W_new
                #print(W)
                V_new = np.append(learning_rate*bias_v,V_new,axis=1)
                V = V - (learning_rate/25)*V_new
                error_train+= error
                count+=1
                #print(error1)
                #print(V.shape)
            #print(error)
            #print(j)
            error, O_softmax = forward_pass(X[0:3200, :], W, V, Y[0 : 3200, :])
            error1, O_softmax = forward_pass(X[3200:4000, :], W, V, Y[3200:4000, :])
            print
            error_validation = error1
            count = train_data_len/batch_size
            count1= validation_data_len/batch_size
            error_train = error_train/count
            print("Training error after  epoch : "+str(j+1)+" here every batch size = 25")
            print(error_train)
            print("Validation error after  epoch : "+str(j+1)+" here batch size = 25")
            print(error_validation)
            train_error_epoch.append(error_train)
            validation_error_epoch.append(error_validation)
    print("\n")
    print("Final Training Errors after 5 trails and 100 Epocs : ")
    print(train_error_epoch)
    print("\n")
    print("Final Validation Errors after 5 trails and 100 Epocs : ")
    print(validation_error_epoch)
    mean_training = []
    variance_training = []
    mean_validation = []
    variance_validation = []
    train_error_epoch = np.reshape(train_error_epoch,(trails,number_of_epocs))
    validation_error_epoch = np.reshape(validation_error_epoch,(trails,number_of_epocs))
    mean_training = np.mean(train_error_epoch, axis=0)
    mean_validation = np.mean(validation_error_epoch,axis=0)
    variance_training = np.var(train_error_epoch,axis=0)
    variance_validation = np.var(validation_error_epoch,axis=0)
    mean_training = np.reshape(mean_training,(number_of_epocs,))
    mean_validation = np.reshape(mean_validation, (number_of_epocs))
    variance_training = np.reshape(variance_training,(number_of_epocs,))
    variance_validation = np.reshape(variance_validation,(number_of_epocs,))
    epochs = []
    for i in range(1,number_of_epocs+1) :
        epochs.append(i)
    print("\n")
    print("Plots are started to Generate In Figures Folder : ")
    plt.plot(epochs,mean_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    #plt.title("Plot for Training Error Vs Epochs")
    location = "./figures/lab3.a_TrainingError" + ".png"
    #plt.savefig(location)
    #plt.close()
    plt.plot(epochs, mean_validation,color='blue', label='Validation')
    plt.ylabel("Training,Validation Error values")
    plt.title("Plot for Training,Validation Error Vs Epochs")
    plt.legend(loc='best')
    location = "./figures/lab3.a_TrainingAndValidationError" + ".png"
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.0145,0.01465)
    plt.plot(epochs, mean_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    plt.ylabel("Mean Training Error values")
    plt.title("Plot for Mean Training Error Vs Epochs")
    location = "./figures/lab3.a_MeanTrainingError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.0133, 0.134)
    plt.plot(epochs, mean_validation, color='blue', label='Validation')
    plt.xlabel("Epoch values")
    plt.ylabel(" Mean Validation Error values")
    plt.title("Plot for Mean Validation Error Vs Epochs")
    location = "./figures/lab3.a_MeanValidationError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.000240, 0.000242)
    plt.plot(epochs, variance_training, color='red', label='Training')
    plt.xlabel("Epoch values")
    plt.ylabel(" Variance Training Error values")
    plt.title("Plot for Variance Training Error Vs Epochs")
    location = "./figures/lab3.a_VarianceTrainingError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    #plt.ylim(0.000210, 0.000211)
    plt.plot(epochs, variance_validation, color='blue', label='Validation')
    plt.xlabel("Epoch values")
    plt.ylabel("Variance Validation Error values")
    plt.title("Plot for Variance Validation Error Vs Epochs")
    location = "./figures/lab3.a_VarianceValidationError" + ".png"
    plt.legend(loc='best')
    plt.savefig(location)
    plt.close()
    print("\n")
    print("Plots are Generated Successfully In Figures folder")
# Out:
# Started calculating Training error in 5 Trails for each epoch with Batch size = 25
# Started calculating Validation error in 5 Trails for each epoch with Batch size = 25
# Training Error for 100th epoch for Trail Number : 1
# Training error after  epoch : 1 here every batch size = 25
# 2.1389176688535296
# Validation error after  epoch : 1 here batch size = 25
# 1.9125154055417166
# Training error after  epoch : 2 here every batch size = 25
# 1.7505153020801207
# Validation error after  epoch : 2 here batch size = 25
# 1.5924636016003502
# Training error after  epoch : 3 here every batch size = 25
# 1.4810240903301577
# Validation error after  epoch : 3 here batch size = 25
# 1.363394402275896
# Training error after  epoch : 4 here every batch size = 25
# 1.2864411340340811
# Validation error after  epoch : 4 here batch size = 25
# 1.1961489703292845
# Training error after  epoch : 5 here every batch size = 25
# 1.1427827939013036
# Validation error after  epoch : 5 here batch size = 25
# 1.071397832714997
# Training error after  epoch : 6 here every batch size = 25
# 1.0342707547147414
# Validation error after  epoch : 6 here batch size = 25
# 0.97628544695881
# Training error after  epoch : 7 here every batch size = 25
# 0.9503973992901135
# Validation error after  epoch : 7 here batch size = 25
# 0.9021490164840081
# Training error after  epoch : 8 here every batch size = 25
# 0.8840722801886401
# Validation error after  epoch : 8 here batch size = 25
# 0.8430769465369171
# Training error after  epoch : 9 here every batch size = 25
# 0.8304599546773858
# Validation error after  epoch : 9 here batch size = 25
# 0.7950003331260395
# Training error after  epoch : 10 here every batch size = 25
# 0.7862320562351475
# Validation error after  epoch : 10 here batch size = 25
# 0.7550974450923743
# Training error after  epoch : 11 here every batch size = 25
# 0.7490733961752234
# Validation error after  epoch : 11 here batch size = 25
# 0.7213939227586417
# Training error after  epoch : 12 here every batch size = 25
# 0.7173523924443337
# Validation error after  epoch : 12 here batch size = 25
# 0.6924919719844563
# Training error after  epoch : 13 here every batch size = 25
# 0.6899005331682876
# Validation error after  epoch : 13 here batch size = 25
# 0.6673868140214806
# Training error after  epoch : 14 here every batch size = 25
# 0.6658649301017995
# Validation error after  epoch : 14 here batch size = 25
# 0.6453427668031679
# Training error after  epoch : 15 here every batch size = 25
# 0.6446099820633214
# Validation error after  epoch : 15 here batch size = 25
# 0.6258100023725772
# Training error after  epoch : 16 here every batch size = 25
# 0.6256518745927957
# Validation error after  epoch : 16 here batch size = 25
# 0.608368780331831
# Training error after  epoch : 17 here every batch size = 25
# 0.6086148312949267
# Validation error after  epoch : 17 here batch size = 25
# 0.5926920179693398
# Training error after  epoch : 18 here every batch size = 25
# 0.5932016438178759
# Validation error after  epoch : 18 here batch size = 25
# 0.5785199795645898
# Training error after  epoch : 19 here every batch size = 25
# 0.5791735300283094
# Validation error after  epoch : 19 here batch size = 25
# 0.5656429400585925
# Training error after  epoch : 20 here every batch size = 25
# 0.5663360978433474
# Validation error after  epoch : 20 here batch size = 25
# 0.5538891063695494
# Training error after  epoch : 21 here every batch size = 25
# 0.5545293425298344
# Validation error after  epoch : 21 here batch size = 25
# 0.5431160340394321
# Training error after  epoch : 22 here every batch size = 25
# 0.5436203509439367
# Validation error after  epoch : 22 here batch size = 25
# 0.5332043990669036
# Training error after  epoch : 23 here every batch size = 25
# 0.5334978601555246
# Validation error after  epoch : 23 here batch size = 25
# 0.5240533838000347
# Training error after  epoch : 24 here every batch size = 25
# 0.524068116043423
# Validation error after  epoch : 24 here batch size = 25
# 0.5155771898765835
# Training error after  epoch : 25 here every batch size = 25
# 0.5152516647996123
# Validation error after  epoch : 25 here batch size = 25
# 0.507702353334883
# Training error after  epoch : 26 here every batch size = 25
# 0.5069808289457022
# Validation error after  epoch : 26 here batch size = 25
# 0.5003656414480133
# Training error after  epoch : 27 here every batch size = 25
# 0.4991976957954638
# Validation error after  epoch : 27 here batch size = 25
# 0.49351237910398743
# Training error after  epoch : 28 here every batch size = 25
# 0.49185249642841794
# Validation error after  epoch : 28 here batch size = 25
# 0.48709509797847983
# Training error after  epoch : 29 here every batch size = 25
# 0.484902286942538
# Validation error after  epoch : 29 here batch size = 25
# 0.4810724325053357
# Training error after  epoch : 30 here every batch size = 25
# 0.4783098669449987
# Validation error after  epoch : 30 here batch size = 25
# 0.47540820780105525
# Training error after  epoch : 31 here every batch size = 25
# 0.47204288653882864
# Validation error after  epoch : 31 here batch size = 25
# 0.47007067942074426
# Training error after  epoch : 32 here every batch size = 25
# 0.4660731047304869
# Validation error after  epoch : 32 here batch size = 25
# 0.4650318951610615
# Training error after  epoch : 33 here every batch size = 25
# 0.46037577066759156
# Validation error after  epoch : 33 here batch size = 25
# 0.4602671564352683
# Training error after  epoch : 34 here every batch size = 25
# 0.45492910537211223
# Validation error after  epoch : 34 here batch size = 25
# 0.4557545619469041
# Training error after  epoch : 35 here every batch size = 25
# 0.44971386630766774
# Validation error after  epoch : 35 here batch size = 25
# 0.4514746201192672
# Training error after  epoch : 36 here every batch size = 25
# 0.44471298065499576
# Validation error after  epoch : 36 here batch size = 25
# 0.44740991944396696
# Training error after  epoch : 37 here every batch size = 25
# 0.43991123587816244
# Validation error after  epoch : 37 here batch size = 25
# 0.443544847906417
# Training error after  epoch : 38 here every batch size = 25
# 0.43529501826532746
# Validation error after  epoch : 38 here batch size = 25
# 0.4398653541478767
# Training error after  epoch : 39 here every batch size = 25
# 0.4308520917781343
# Validation error after  epoch : 39 here batch size = 25
# 0.43635874418373083
# Training error after  epoch : 40 here every batch size = 25
# 0.42657141085521
# Validation error after  epoch : 40 here batch size = 25
# 0.43301350841939046
# Training error after  epoch : 41 here every batch size = 25
# 0.4224429618689392
# Validation error after  epoch : 41 here batch size = 25
# 0.429819174458052
# Training error after  epoch : 42 here every batch size = 25
# 0.41845762879001575
# Validation error after  epoch : 42 here batch size = 25
# 0.42676618182483594
# Training error after  epoch : 43 here every batch size = 25
# 0.4146070793151196
# Validation error after  epoch : 43 here batch size = 25
# 0.4238457752699899
# Training error after  epoch : 44 here every batch size = 25
# 0.41088366829237044
# Validation error after  epoch : 44 here batch size = 25
# 0.4210499137798567
# Training error after  epoch : 45 here every batch size = 25
# 0.40728035576183697
# Validation error after  epoch : 45 here batch size = 25
# 0.41837119283137525
# Training error after  epoch : 46 here every batch size = 25
# 0.40379063733340037
# Validation error after  epoch : 46 here batch size = 25
# 0.4158027777829026
# Training error after  epoch : 47 here every batch size = 25
# 0.40040848496636916
# Validation error after  epoch : 47 here batch size = 25
# 0.4133383466074085
# Training error after  epoch : 48 here every batch size = 25
# 0.39712829650579484
# Validation error after  epoch : 48 here batch size = 25
# 0.41097204044834
# Training error after  epoch : 49 here every batch size = 25
# 0.39394485257835193
# Validation error after  epoch : 49 here batch size = 25
# 0.4086984207175155
# Training error after  epoch : 50 here every batch size = 25
# 0.3908532796628607
# Validation error after  epoch : 50 here batch size = 25
# 0.40651243166164575
# Training error after  epoch : 51 here every batch size = 25
# 0.3878490183326417
# Validation error after  epoch : 51 here batch size = 25
# 0.4044093675025619
# Training error after  epoch : 52 here every batch size = 25
# 0.38492779582321685
# Validation error after  epoch : 52 here batch size = 25
# 0.40238484340884995
# Training error after  epoch : 53 here every batch size = 25
# 0.38208560221311066
# Validation error after  epoch : 53 here batch size = 25
# 0.4004347696861552
# Training error after  epoch : 54 here every batch size = 25
# 0.3793186696205372
# Validation error after  epoch : 54 here batch size = 25
# 0.3985553286825367
# Training error after  epoch : 55 here every batch size = 25
# 0.3766234539171225
# Validation error after  epoch : 55 here batch size = 25
# 0.3967429539964896
# Training error after  epoch : 56 here every batch size = 25
# 0.37399661854363736
# Validation error after  epoch : 56 here batch size = 25
# 0.3949943116509168
# Training error after  epoch : 57 here every batch size = 25
# 0.37143502008384865
# Validation error after  epoch : 57 here batch size = 25
# 0.3933062829586354
# Training error after  epoch : 58 here every batch size = 25
# 0.36893569531268006
# Validation error after  epoch : 58 here batch size = 25
# 0.3916759488559137
# Training error after  epoch : 59 here every batch size = 25
# 0.3664958494853917
# Validation error after  epoch : 59 here batch size = 25
# 0.39010057552182575
# Training error after  epoch : 60 here every batch size = 25
# 0.3641128456766854
# Validation error after  epoch : 60 here batch size = 25
# 0.38857760113448636
# Training error after  epoch : 61 here every batch size = 25
# 0.361784195013745
# Validation error after  epoch : 61 here batch size = 25
# 0.3871046236418435
# Training error after  epoch : 62 here every batch size = 25
# 0.35950754767619203
# Validation error after  epoch : 62 here batch size = 25
# 0.38567938944587365
# Training error after  epoch : 63 here every batch size = 25
# 0.3572806845597736
# Validation error after  epoch : 63 here batch size = 25
# 0.3842997829157625
# Training error after  epoch : 64 here every batch size = 25
# 0.35510150952002023
# Validation error after  epoch : 64 here batch size = 25
# 0.38296381665882406
# Training error after  epoch : 65 here every batch size = 25
# 0.352968042127895
# Validation error after  epoch : 65 here batch size = 25
# 0.3816696224882382
# Training error after  epoch : 66 here every batch size = 25
# 0.35087841088217925
# Validation error after  epoch : 66 here batch size = 25
# 0.3804154430347698
# Training error after  epoch : 67 here every batch size = 25
# 0.34883084683353627
# Validation error after  epoch : 67 here batch size = 25
# 0.379199623955966
# Training error after  epoch : 68 here every batch size = 25
# 0.34682367758331056
# Validation error after  epoch : 68 here batch size = 25
# 0.378020606701303
# Training error after  epoch : 69 here every batch size = 25
# 0.3448553216265699
# Validation error after  epoch : 69 here batch size = 25
# 0.3768769217956918
# Training error after  epoch : 70 here every batch size = 25
# 0.3429242830139519
# Validation error after  epoch : 70 here batch size = 25
# 0.3757671826069171
# Training error after  epoch : 71 here every batch size = 25
# 0.34102914631084863
# Validation error after  epoch : 71 here batch size = 25
# 0.3746900795651507
# Training error after  epoch : 72 here every batch size = 25
# 0.3391685718355485
# Validation error after  epoch : 72 here batch size = 25
# 0.3736443748048341
# Training error after  epoch : 73 here every batch size = 25
# 0.33734129116036216
# Validation error after  epoch : 73 here batch size = 25
# 0.3726288972010503
# Training error after  epoch : 74 here every batch size = 25
# 0.3355461028616076
# Validation error after  epoch : 74 here batch size = 25
# 0.37164253777411943
# Training error after  epoch : 75 here every batch size = 25
# 0.33378186850576425
# Validation error after  epoch : 75 here batch size = 25
# 0.3706842454375953
# Training error after  epoch : 76 here every batch size = 25
# 0.3320475088602187
# Validation error after  epoch : 76 here batch size = 25
# 0.3697530230661769
# Training error after  epoch : 77 here every batch size = 25
# 0.33034200031788474
# Validation error after  epoch : 77 here batch size = 25
# 0.3688479238613016
# Training error after  epoch : 78 here every batch size = 25
# 0.3286643715256593
# Validation error after  epoch : 78 here batch size = 25
# 0.36796804799338045
# Training error after  epoch : 79 here every batch size = 25
# 0.32701370020721515
# Validation error after  epoch : 79 here batch size = 25
# 0.3671125395007862
# Training error after  epoch : 80 here every batch size = 25
# 0.3253891101710723
# Validation error after  epoch : 80 here batch size = 25
# 0.3662805834268144
# Training error after  epoch : 81 here every batch size = 25
# 0.3237897684952569
# Validation error after  epoch : 81 here batch size = 25
# 0.36547140317692295
# Training error after  epoch : 82 here every batch size = 25
# 0.3222148828801737
# Validation error after  epoch : 82 here batch size = 25
# 0.36468425807960064
# Training error after  epoch : 83 here every batch size = 25
# 0.3206636991615964
# Validation error after  epoch : 83 here batch size = 25
# 0.3639184411352385
# Training error after  epoch : 84 here every batch size = 25
# 0.3191354989759545
# Validation error after  epoch : 84 here batch size = 25
# 0.363173276938362
# Training error after  epoch : 85 here every batch size = 25
# 0.31762959757031745
# Validation error after  epoch : 85 here batch size = 25
# 0.3624481197595392
# Training error after  epoch : 86 here every batch size = 25
# 0.31614534174973075
# Validation error after  epoch : 86 here batch size = 25
# 0.3617423517741989
# Training error after  epoch : 87 here every batch size = 25
# 0.31468210795478957
# Validation error after  epoch : 87 here batch size = 25
# 0.3610553814264733
# Training error after  epoch : 88 here every batch size = 25
# 0.3132393004625491
# Validation error after  epoch : 88 here batch size = 25
# 0.36038664191702674
# Training error after  epoch : 89 here every batch size = 25
# 0.31181634970411837
# Validation error after  epoch : 89 here batch size = 25
# 0.3597355898046355
# Training error after  epoch : 90 here every batch size = 25
# 0.31041271069249793
# Validation error after  epoch : 90 here batch size = 25
# 0.3591017037120494
# Training error after  epoch : 91 here every batch size = 25
# 0.3090278615544591
# Validation error after  epoch : 91 here batch size = 25
# 0.3584844831273894
# Training error after  epoch : 92 here every batch size = 25
# 0.30766130216048204
# Validation error after  epoch : 92 here batch size = 25
# 0.35788344729302
# Training error after  epoch : 93 here every batch size = 25
# 0.3063125528470097
# Validation error after  epoch : 93 here batch size = 25
# 0.3572981341744787
# Training error after  epoch : 94 here every batch size = 25
# 0.30498115322548613
# Validation error after  epoch : 94 here batch size = 25
# 0.35672809950264733
# Training error after  epoch : 95 here every batch size = 25
# 0.30366666107289114
# Validation error after  epoch : 95 here batch size = 25
# 0.35617291588291505
# Training error after  epoch : 96 here every batch size = 25
# 0.3023686512986916
# Validation error after  epoch : 96 here batch size = 25
# 0.3556321719656109
# Training error after  epoch : 97 here every batch size = 25
# 0.3010867149833642
# Validation error after  epoch : 97 here batch size = 25
# 0.35510547167246953
# Training error after  epoch : 98 here every batch size = 25
# 0.2998204584838577
# Validation error after  epoch : 98 here batch size = 25
# 0.35459243347435204
# Training error after  epoch : 99 here every batch size = 25
# 0.2985695026015775
# Validation error after  epoch : 99 here batch size = 25
# 0.35409268971586044
# Training error after  epoch : 100 here every batch size = 25
# 0.2973334818086978
# Validation error after  epoch : 100 here batch size = 25
# 0.3536058859828738
# Training Error for 100th epoch for Trail Number : 2
# Training error after  epoch : 1 here every batch size = 25
# 2.0641973041330934
# Validation error after  epoch : 1 here batch size = 25
# 1.8696092190007227
# Training error after  epoch : 2 here every batch size = 25
# 1.6843316819809606
# Validation error after  epoch : 2 here batch size = 25
# 1.5659580310972172
# Training error after  epoch : 3 here every batch size = 25
# 1.4202310092764239
# Validation error after  epoch : 3 here batch size = 25
# 1.3501008853245426
# Training error after  epoch : 4 here every batch size = 25
# 1.233239711992747
# Validation error after  epoch : 4 here batch size = 25
# 1.1942555930050553
# Training error after  epoch : 5 here every batch size = 25
# 1.0980232578794147
# Validation error after  epoch : 5 here batch size = 25
# 1.0789623804352295
# Training error after  epoch : 6 here every batch size = 25
# 0.9971477640741055
# Validation error after  epoch : 6 here batch size = 25
# 0.9911366091805011
# Training error after  epoch : 7 here every batch size = 25
# 0.9193689457370462
# Validation error after  epoch : 7 here batch size = 25
# 0.9222811385982268
# Training error after  epoch : 8 here every batch size = 25
# 0.8575765065703634
# Validation error after  epoch : 8 here batch size = 25
# 0.866889220228893
# Training error after  epoch : 9 here every batch size = 25
# 0.80721795736433
# Validation error after  epoch : 9 here batch size = 25
# 0.8213333215439198
# Training error after  epoch : 10 here every batch size = 25
# 0.7652996079356705
# Validation error after  epoch : 10 here batch size = 25
# 0.7831625917287449
# Training error after  epoch : 11 here every batch size = 25
# 0.7297884265606432
# Validation error after  epoch : 11 here batch size = 25
# 0.75067299304791
# Training error after  epoch : 12 here every batch size = 25
# 0.6992583092312898
# Validation error after  epoch : 12 here batch size = 25
# 0.7226455917374645
# Training error after  epoch : 13 here every batch size = 25
# 0.672678908799203
# Validation error after  epoch : 13 here batch size = 25
# 0.6981855631211635
# Training error after  epoch : 14 here every batch size = 25
# 0.6492865834559725
# Validation error after  epoch : 14 here batch size = 25
# 0.6766211087824141
# Training error after  epoch : 15 here every batch size = 25
# 0.6285030348523668
# Validation error after  epoch : 15 here batch size = 25
# 0.6574382686101259
# Training error after  epoch : 16 here every batch size = 25
# 0.6098822863756028
# Validation error after  epoch : 16 here batch size = 25
# 0.6402376088270136
# Training error after  epoch : 17 here every batch size = 25
# 0.5930750327971669
# Validation error after  epoch : 17 here batch size = 25
# 0.6247045677397233
# Training error after  epoch : 18 here every batch size = 25
# 0.577803990985472
# Validation error after  epoch : 18 here batch size = 25
# 0.6105885762185469
# Training error after  epoch : 19 here every batch size = 25
# 0.563846435367248
# Validation error after  epoch : 19 here batch size = 25
# 0.5976879924224917
# Training error after  epoch : 20 here every batch size = 25
# 0.5510215591724886
# Validation error after  epoch : 20 here batch size = 25
# 0.5858390094767093
# Training error after  epoch : 21 here every batch size = 25
# 0.5391811603404597
# Validation error after  epoch : 21 here batch size = 25
# 0.574907356347712
# Training error after  epoch : 22 here every batch size = 25
# 0.5282026707277859
# Validation error after  epoch : 22 here batch size = 25
# 0.5647820112175357
# Training error after  epoch : 23 here every batch size = 25
# 0.5179838704335875
# Validation error after  epoch : 23 here batch size = 25
# 0.5553703937132098
# Training error after  epoch : 24 here every batch size = 25
# 0.5084388349840343
# Validation error after  epoch : 24 here batch size = 25
# 0.546594660192803
# Training error after  epoch : 25 here every batch size = 25
# 0.49949479761641524
# Validation error after  epoch : 25 here batch size = 25
# 0.5383888307428208
# Training error after  epoch : 26 here every batch size = 25
# 0.49108969897686433
# Validation error after  epoch : 26 here batch size = 25
# 0.53069654814772
# Training error after  epoch : 27 here every batch size = 25
# 0.4831702583637952
# Validation error after  epoch : 27 here batch size = 25
# 0.5234693197638604
# Training error after  epoch : 28 here every batch size = 25
# 0.4756904440418288
# Validation error after  epoch : 28 here batch size = 25
# 0.5166651300184181
# Training error after  epoch : 29 here every batch size = 25
# 0.46861025121096594
# Validation error after  epoch : 29 here batch size = 25
# 0.5102473384673654
# Training error after  epoch : 30 here every batch size = 25
# 0.4618947188074164
# Validation error after  epoch : 30 here batch size = 25
# 0.5041837987300893
# Training error after  epoch : 31 here every batch size = 25
# 0.4555131329534151
# Validation error after  epoch : 31 here batch size = 25
# 0.4984461490015255
# Training error after  epoch : 32 here every batch size = 25
# 0.4494383772494495
# Validation error after  epoch : 32 here batch size = 25
# 0.493009236499384
# Training error after  epoch : 33 here every batch size = 25
# 0.44364639937342043
# Validation error after  epoch : 33 here batch size = 25
# 0.48785064705232695
# Training error after  epoch : 34 here every batch size = 25
# 0.43811577043431255
# Validation error after  epoch : 34 here batch size = 25
# 0.4829503177538419
# Training error after  epoch : 35 here every batch size = 25
# 0.4328273188103491
# Validation error after  epoch : 35 here batch size = 25
# 0.47829021570688846
# Training error after  epoch : 36 here every batch size = 25
# 0.4277638242124772
# Validation error after  epoch : 36 here batch size = 25
# 0.47385406975424393
# Training error after  epoch : 37 here every batch size = 25
# 0.42290976077065473
# Validation error after  epoch : 37 here batch size = 25
# 0.4696271450252298
# Training error after  epoch : 38 here every batch size = 25
# 0.4182510802793422
# Validation error after  epoch : 38 here batch size = 25
# 0.4655960523577775
# Training error after  epoch : 39 here every batch size = 25
# 0.41377502853695036
# Validation error after  epoch : 39 here batch size = 25
# 0.4617485863487329
# Training error after  epoch : 40 here every batch size = 25
# 0.40946998910472504
# Validation error after  epoch : 40 here batch size = 25
# 0.45807358707676643
# Training error after  epoch : 41 here every batch size = 25
# 0.4053253498933285
# Validation error after  epoch : 41 here batch size = 25
# 0.45456082153130944
# Training error after  epoch : 42 here every batch size = 25
# 0.40133138883498504
# Validation error after  epoch : 42 here batch size = 25
# 0.451200881543095
# Training error after  epoch : 43 here every batch size = 25
# 0.3974791755713552
# Validation error after  epoch : 43 here batch size = 25
# 0.4479850956038905
# Training error after  epoch : 44 here every batch size = 25
# 0.3937604866240574
# Validation error after  epoch : 44 here batch size = 25
# 0.4449054524272444
# Training error after  epoch : 45 here every batch size = 25
# 0.39016773194713483
# Validation error after  epoch : 45 here batch size = 25
# 0.44195453447005406
# Training error after  epoch : 46 here every batch size = 25
# 0.3866938911120715
# Validation error after  epoch : 46 here batch size = 25
# 0.439125459929819
# Training error after  epoch : 47 here every batch size = 25
# 0.38333245766366025
# Validation error after  epoch : 47 here batch size = 25
# 0.4364118319717879
# Training error after  epoch : 48 here every batch size = 25
# 0.38007739042226163
# Validation error after  epoch : 48 here batch size = 25
# 0.43380769413653325
# Training error after  epoch : 49 here every batch size = 25
# 0.3769230707047699
# Validation error after  epoch : 49 here batch size = 25
# 0.43130749104112204
# Training error after  epoch : 50 here every batch size = 25
# 0.3738642646005665
# Validation error after  epoch : 50 here batch size = 25
# 0.42890603362293633
# Training error after  epoch : 51 here every batch size = 25
# 0.37089608957581827
# Validation error after  epoch : 51 here batch size = 25
# 0.4265984682894755
# Training error after  epoch : 52 here every batch size = 25
# 0.3680139847943583
# Validation error after  epoch : 52 here batch size = 25
# 0.42438024943404146
# Training error after  epoch : 53 here every batch size = 25
# 0.3652136846397714
# Validation error after  epoch : 53 here batch size = 25
# 0.4222471148590579
# Training error after  epoch : 54 here every batch size = 25
# 0.36249119500420596
# Validation error after  epoch : 54 here batch size = 25
# 0.42019506371823895
# Training error after  epoch : 55 here every batch size = 25
# 0.359842771977338
# Validation error after  epoch : 55 here batch size = 25
# 0.4182203366477764
# Training error after  epoch : 56 here every batch size = 25
# 0.3572649026258343
# Validation error after  epoch : 56 here batch size = 25
# 0.41631939780670635
# Training error after  epoch : 57 here every batch size = 25
# 0.3547542876013634
# Validation error after  epoch : 57 here batch size = 25
# 0.414488918588912
# Training error after  epoch : 58 here every batch size = 25
# 0.35230782535507854
# Validation error after  epoch : 58 here batch size = 25
# 0.4127257628049473
# Training error after  epoch : 59 here every batch size = 25
# 0.34992259776985346
# Validation error after  epoch : 59 here batch size = 25
# 0.41102697316194664
# Training error after  epoch : 60 here every batch size = 25
# 0.34759585704935786
# Validation error after  epoch : 60 here batch size = 25
# 0.40938975889516216
# Training error after  epoch : 61 here every batch size = 25
# 0.34532501372627106
# Validation error after  epoch : 61 here batch size = 25
# 0.40781148442586196
# Training error after  epoch : 62 here every batch size = 25
# 0.3431076256712907
# Validation error after  epoch : 62 here batch size = 25
# 0.4062896589380439
# Training error after  epoch : 63 here every batch size = 25
# 0.34094138800072854
# Validation error after  epoch : 63 here batch size = 25
# 0.40482192678123724
# Training error after  epoch : 64 here every batch size = 25
# 0.3388241237939735
# Validation error after  epoch : 64 here batch size = 25
# 0.40340605861903506
# Training error after  epoch : 65 here every batch size = 25
# 0.33675377554338853
# Validation error after  epoch : 65 here batch size = 25
# 0.40203994325334563
# Training error after  epoch : 66 here every batch size = 25
# 0.3347283972686719
# Validation error after  epoch : 66 here batch size = 25
# 0.4007215800630015
# Training error after  epoch : 67 here every batch size = 25
# 0.3327461472356974
# Validation error after  epoch : 67 here batch size = 25
# 0.3994490720026313
# Training error after  epoch : 68 here every batch size = 25
# 0.330805281226602
# Validation error after  epoch : 68 here batch size = 25
# 0.3982206191138203
# Training error after  epoch : 69 here every batch size = 25
# 0.3289041463136357
# Validation error after  epoch : 69 here batch size = 25
# 0.397034512505764
# Training error after  epoch : 70 here every batch size = 25
# 0.32704117509422026
# Validation error after  epoch : 70 here batch size = 25
# 0.395889128767039
# Training error after  epoch : 71 here every batch size = 25
# 0.3252148803489019
# Validation error after  epoch : 71 here batch size = 25
# 0.394782924773897
# Training error after  epoch : 72 here every batch size = 25
# 0.32342385008758273
# Validation error after  epoch : 72 here batch size = 25
# 0.39371443286376434
# Training error after  epoch : 73 here every batch size = 25
# 0.3216667429526317
# Validation error after  epoch : 73 here batch size = 25
# 0.3926822563454828
# Training error after  epoch : 74 here every batch size = 25
# 0.3199422839503342
# Validation error after  epoch : 74 here batch size = 25
# 0.3916850653203297
# Training error after  epoch : 75 here every batch size = 25
# 0.31824926048464386
# Validation error after  epoch : 75 here batch size = 25
# 0.39072159279007634
# Training error after  epoch : 76 here every batch size = 25
# 0.3165865186694689
# Validation error after  epoch : 76 here batch size = 25
# 0.3897906310303232
# Training error after  epoch : 77 here every batch size = 25
# 0.314952959897728
# Validation error after  epoch : 77 here batch size = 25
# 0.3888910282091247
# Training error after  epoch : 78 here every batch size = 25
# 0.31334753764724665
# Validation error after  epoch : 78 here batch size = 25
# 0.3880216852325236
# Training error after  epoch : 79 here every batch size = 25
# 0.3117692545052037
# Validation error after  epoch : 79 here batch size = 25
# 0.3871815528000741
# Training error after  epoch : 80 here every batch size = 25
# 0.3102171593943443
# Validation error after  epoch : 80 here batch size = 25
# 0.3863696286547561
# Training error after  epoch : 81 here every batch size = 25
# 0.3086903449855347
# Validation error after  epoch : 81 here batch size = 25
# 0.3855849550129084
# Training error after  epoch : 82 here every batch size = 25
# 0.30718794528249105
# Validation error after  epoch : 82 here batch size = 25
# 0.38482661616091435
# Training error after  epoch : 83 here every batch size = 25
# 0.3057091333656457
# Validation error after  epoch : 83 here batch size = 25
# 0.38409373620640624
# Training error after  epoch : 84 here every batch size = 25
# 0.3042531192831745
# Validation error after  epoch : 84 here batch size = 25
# 0.3833854769726952
# Training error after  epoch : 85 here every batch size = 25
# 0.30281914807815513
# Validation error after  epoch : 85 here batch size = 25
# 0.38270103602600514
# Training error after  epoch : 86 here every batch size = 25
# 0.3014064979417181
# Validation error after  epoch : 86 here batch size = 25
# 0.38203964482588815
# Training error after  epoch : 87 here every batch size = 25
# 0.3000144784828615
# Validation error after  epoch : 87 here batch size = 25
# 0.3814005669899434
# Training error after  epoch : 88 here every batch size = 25
# 0.29864242910633954
# Validation error after  epoch : 88 here batch size = 25
# 0.38078309666463994
# Training error after  epoch : 89 here every batch size = 25
# 0.2972897174907198
# Validation error after  epoch : 89 here batch size = 25
# 0.3801865569946738
# Training error after  epoch : 90 here every batch size = 25
# 0.29595573815934517
# Validation error after  epoch : 90 here batch size = 25
# 0.37961029868387514
# Training error after  epoch : 91 here every batch size = 25
# 0.2946399111374933
# Validation error after  epoch : 91 here batch size = 25
# 0.37905369864120897
# Training error after  epoch : 92 here every batch size = 25
# 0.29334168068957733
# Validation error after  epoch : 92 here batch size = 25
# 0.37851615870591504
# Training error after  epoch : 93 here every batch size = 25
# 0.29206051413071316
# Validation error after  epoch : 93 here batch size = 25
# 0.3779971044462815
# Training error after  epoch : 94 here every batch size = 25
# 0.2907959007074191
# Validation error after  epoch : 94 here batch size = 25
# 0.37749598402697315
# Training error after  epoch : 95 here every batch size = 25
# 0.28954735054264336
# Validation error after  epoch : 95 here batch size = 25
# 0.37701226714021646
# Training error after  epoch : 96 here every batch size = 25
# 0.28831439364067896
# Validation error after  epoch : 96 here batch size = 25
# 0.37654544399650375
# Training error after  epoch : 97 here every batch size = 25
# 0.2870965789478813
# Validation error after  epoch : 97 here batch size = 25
# 0.3760950243708103
# Training error after  epoch : 98 here every batch size = 25
# 0.2858934734654187
# Validation error after  epoch : 98 here batch size = 25
# 0.37566053670061605
# Training error after  epoch : 99 here every batch size = 25
# 0.28470466141058826
# Validation error after  epoch : 99 here batch size = 25
# 0.37524152723230836
# Training error after  epoch : 100 here every batch size = 25
# 0.28352974342348575
# Validation error after  epoch : 100 here batch size = 25
# 0.3748375592127988
# Training Error for 100th epoch for Trail Number : 3
# Training error after  epoch : 1 here every batch size = 25
# 2.087695523729325
# Validation error after  epoch : 1 here batch size = 25
# 1.8497979690352293
# Training error after  epoch : 2 here every batch size = 25
# 1.7105518471081813
# Validation error after  epoch : 2 here batch size = 25
# 1.535518196452652
# Training error after  epoch : 3 here every batch size = 25
# 1.4459717728464208
# Validation error after  epoch : 3 here batch size = 25
# 1.3106880546138262
# Training error after  epoch : 4 here every batch size = 25
# 1.2560770051672223
# Validation error after  epoch : 4 here batch size = 25
# 1.1479834118346304
# Training error after  epoch : 5 here every batch size = 25
# 1.1177961378486903
# Validation error after  epoch : 5 here batch size = 25
# 1.0276763884527376
# Training error after  epoch : 6 here every batch size = 25
# 1.0144973872762058
# Validation error after  epoch : 6 here batch size = 25
# 0.9360418972663274
# Training error after  epoch : 7 here every batch size = 25
# 0.9349163747970727
# Validation error after  epoch : 7 here batch size = 25
# 0.8641589549942621
# Training error after  epoch : 8 here every batch size = 25
# 0.8718153817635266
# Validation error after  epoch : 8 here batch size = 25
# 0.806304982569622
# Training error after  epoch : 9 here every batch size = 25
# 0.820538403685608
# Validation error after  epoch : 9 here batch size = 25
# 0.7587265690483607
# Training error after  epoch : 10 here every batch size = 25
# 0.7780084826458181
# Validation error after  epoch : 10 here batch size = 25
# 0.7188820661831227
# Training error after  epoch : 11 here every batch size = 25
# 0.7421236796704355
# Validation error after  epoch : 11 here batch size = 25
# 0.6849962264607958
# Training error after  epoch : 12 here every batch size = 25
# 0.7114020368092805
# Validation error after  epoch : 12 here batch size = 25
# 0.6557947567281778
# Training error after  epoch : 13 here every batch size = 25
# 0.6847693798162552
# Validation error after  epoch : 13 here batch size = 25
# 0.6303410618483851
# Training error after  epoch : 14 here every batch size = 25
# 0.6614284724096885
# Validation error after  epoch : 14 here batch size = 25
# 0.6079324111221062
# Training error after  epoch : 15 here every batch size = 25
# 0.6407755185905165
# Validation error after  epoch : 15 here batch size = 25
# 0.5880318609679157
# Training error after  epoch : 16 here every batch size = 25
# 0.6223451438462206
# Validation error after  epoch : 16 here batch size = 25
# 0.5702224350952174
# Training error after  epoch : 17 here every batch size = 25
# 0.6057731128086713
# Validation error after  epoch : 17 here batch size = 25
# 0.5541755774567022
# Training error after  epoch : 18 here every batch size = 25
# 0.5907704522563877
# Validation error after  epoch : 18 here batch size = 25
# 0.5396289912215968
# Training error after  epoch : 19 here every batch size = 25
# 0.5771051136431158
# Validation error after  epoch : 19 here batch size = 25
# 0.5263707854352793
# Training error after  epoch : 20 here every batch size = 25
# 0.5645887379417466
# Validation error after  epoch : 20 here batch size = 25
# 0.514227943203122
# Training error after  epoch : 21 here every batch size = 25
# 0.5530669436970386
# Validation error after  epoch : 21 here batch size = 25
# 0.5030578033797046
# Training error after  epoch : 22 here every batch size = 25
# 0.5424120913121202
# Validation error after  epoch : 22 here batch size = 25
# 0.492741678412628
# Training error after  epoch : 23 here every batch size = 25
# 0.5325178156908091
# Validation error after  epoch : 23 here batch size = 25
# 0.4831800098220762
# Training error after  epoch : 24 here every batch size = 25
# 0.5232948404966676
# Validation error after  epoch : 24 here batch size = 25
# 0.4742886465034908
# Training error after  epoch : 25 here every batch size = 25
# 0.5146677343564173
# Validation error after  epoch : 25 here batch size = 25
# 0.4659959540574778
# Training error after  epoch : 26 here every batch size = 25
# 0.50657236876663
# Validation error after  epoch : 26 here batch size = 25
# 0.45824054698805994
# Training error after  epoch : 27 here every batch size = 25
# 0.49895390562205394
# Validation error after  epoch : 27 here batch size = 25
# 0.45096949328258334
# Training error after  epoch : 28 here every batch size = 25
# 0.491765189558267
# Validation error after  epoch : 28 here batch size = 25
# 0.4441368811823573
# Training error after  epoch : 29 here every batch size = 25
# 0.48496545343601655
# Validation error after  epoch : 29 here batch size = 25
# 0.4377026664620848
# Training error after  epoch : 30 here every batch size = 25
# 0.47851926875535467
# Validation error after  epoch : 30 here batch size = 25
# 0.43163173895237195
# Training error after  epoch : 31 here every batch size = 25
# 0.47239568957522116
# Validation error after  epoch : 31 here batch size = 25
# 0.4258931618373306
# Training error after  epoch : 32 here every batch size = 25
# 0.4665675506656183
# Validation error after  epoch : 32 here batch size = 25
# 0.42045954811448893
# Training error after  epoch : 33 here every batch size = 25
# 0.461010889526812
# Validation error after  epoch : 33 here batch size = 25
# 0.4153065466629714
# Training error after  epoch : 34 here every batch size = 25
# 0.45570446852833474
# Validation error after  epoch : 34 here batch size = 25
# 0.4104124164185915
# Training error after  epoch : 35 here every batch size = 25
# 0.45062937840736583
# Validation error after  epoch : 35 here batch size = 25
# 0.40575767175082544
# Training error after  epoch : 36 here every batch size = 25
# 0.44576870817587627
# Validation error after  epoch : 36 here batch size = 25
# 0.4013247856625348
# Training error after  epoch : 37 here every batch size = 25
# 0.44110726943460327
# Validation error after  epoch : 37 here batch size = 25
# 0.39709794016261474
# Training error after  epoch : 38 here every batch size = 25
# 0.43663136540100944
# Validation error after  epoch : 38 here batch size = 25
# 0.3930628152911772
# Training error after  epoch : 39 here every batch size = 25
# 0.4323285967850167
# Validation error after  epoch : 39 here batch size = 25
# 0.38920640994959865
# Training error after  epoch : 40 here every batch size = 25
# 0.4281876981035391
# Validation error after  epoch : 40 here batch size = 25
# 0.3855168890094396
# Training error after  epoch : 41 here every batch size = 25
# 0.4241983991954584
# Validation error after  epoch : 41 here batch size = 25
# 0.3819834522238291
# Training error after  epoch : 42 here every batch size = 25
# 0.4203513076442851
# Validation error after  epoch : 42 here batch size = 25
# 0.3785962213021649
# Training error after  epoch : 43 here every batch size = 25
# 0.4166378085829672
# Validation error after  epoch : 43 here batch size = 25
# 0.37534614217952866
# Training error after  epoch : 44 here every batch size = 25
# 0.4130499789800629
# Validation error after  epoch : 44 here batch size = 25
# 0.3722249000512379
# Training error after  epoch : 45 here every batch size = 25
# 0.40958051401670054
# Validation error after  epoch : 45 here batch size = 25
# 0.36922484517769716
# Training error after  epoch : 46 here every batch size = 25
# 0.4062226635814081
# Validation error after  epoch : 46 here batch size = 25
# 0.36633892781645166
# Training error after  epoch : 47 here every batch size = 25
# 0.40297017725254053
# Validation error after  epoch : 47 here batch size = 25
# 0.36356064092374085
# Training error after  epoch : 48 here every batch size = 25
# 0.3998172564195346
# Validation error after  epoch : 48 here batch size = 25
# 0.36088396950000967
# Training error after  epoch : 49 here every batch size = 25
# 0.3967585124258637
# Validation error after  epoch : 49 here batch size = 25
# 0.3583033456431448
# Training error after  epoch : 50 here every batch size = 25
# 0.3937889298073785
# Validation error after  epoch : 50 here batch size = 25
# 0.355813608527894
# Training error after  epoch : 51 here every batch size = 25
# 0.39090383385700966
# Validation error after  epoch : 51 here batch size = 25
# 0.35340996865658725
# Training error after  epoch : 52 here every batch size = 25
# 0.38809886187656706
# Validation error after  epoch : 52 here batch size = 25
# 0.3510879758301864
# Training error after  epoch : 53 here every batch size = 25
# 0.38536993758344285
# Validation error after  epoch : 53 here batch size = 25
# 0.3488434903741021
# Training error after  epoch : 54 here every batch size = 25
# 0.38271324822839753
# Validation error after  epoch : 54 here batch size = 25
# 0.3466726572235727
# Training error after  epoch : 55 here every batch size = 25
# 0.3801252240535604
# Validation error after  epoch : 55 here batch size = 25
# 0.3445718825314994
# Training error after  epoch : 56 here every batch size = 25
# 0.3776025197799926
# Validation error after  epoch : 56 here batch size = 25
# 0.3425378125097342
# Training error after  epoch : 57 here every batch size = 25
# 0.37514199786388025
# Validation error after  epoch : 57 here batch size = 25
# 0.34056731425479086
# Training error after  epoch : 58 here every batch size = 25
# 0.37274071330149156
# Validation error after  epoch : 58 here batch size = 25
# 0.3386574583422724
# Training error after  epoch : 59 here every batch size = 25
# 0.37039589979694426
# Validation error after  epoch : 59 here batch size = 25
# 0.33680550300223516
# Training error after  epoch : 60 here every batch size = 25
# 0.368104957134893
# Validation error after  epoch : 60 here batch size = 25
# 0.335008879711217
# Training error after  epoch : 61 here every batch size = 25
# 0.36586543962346385
# Validation error after  epoch : 61 here batch size = 25
# 0.33326518005655387
# Training error after  epoch : 62 here every batch size = 25
# 0.3636750454920175
# Validation error after  epoch : 62 here batch size = 25
# 0.33157214374556204
# Training error after  epoch : 63 here every batch size = 25
# 0.3615316071443342
# Validation error after  epoch : 63 here batch size = 25
# 0.32992764764668775
# Training error after  epoch : 64 here every batch size = 25
# 0.35943308218114367
# Validation error after  epoch : 64 here batch size = 25
# 0.32832969576225424
# Training error after  epoch : 65 here every batch size = 25
# 0.35737754511707087
# Validation error after  epoch : 65 here batch size = 25
# 0.3267764100433142
# Training error after  epoch : 66 here every batch size = 25
# 0.35536317972644116
# Validation error after  epoch : 66 here batch size = 25
# 0.32526602196661275
# Training error after  epoch : 67 here every batch size = 25
# 0.3533882719602686
# Validation error after  epoch : 67 here batch size = 25
# 0.32379686480201214
# Training error after  epoch : 68 here every batch size = 25
# 0.35145120338345004
# Validation error after  epoch : 68 here batch size = 25
# 0.32236736650609626
# Training error after  epoch : 69 here every batch size = 25
# 0.34955044508688593
# Validation error after  epoch : 69 here batch size = 25
# 0.3209760431842088
# Training error after  epoch : 70 here every batch size = 25
# 0.34768455203413773
# Validation error after  epoch : 70 here batch size = 25
# 0.31962149306900145
# Training error after  epoch : 71 here every batch size = 25
# 0.34585215780644707
# Validation error after  epoch : 71 here batch size = 25
# 0.3183023909687662
# Training error after  epoch : 72 here every batch size = 25
# 0.34405196971359486
# Validation error after  epoch : 72 here batch size = 25
# 0.3170174831434821
# Training error after  epoch : 73 here every batch size = 25
# 0.3422827642412816
# Validation error after  epoch : 73 here batch size = 25
# 0.3157655825706857
# Training error after  epoch : 74 here every batch size = 25
# 0.3405433828084979
# Validation error after  epoch : 74 here batch size = 25
# 0.31454556456702704
# Training error after  epoch : 75 here every batch size = 25
# 0.3388327278108405
# Validation error after  epoch : 75 here batch size = 25
# 0.3133563627347399
# Training error after  epoch : 76 here every batch size = 25
# 0.33714975892791355
# Validation error after  epoch : 76 here batch size = 25
# 0.3121969652052941
# Training error after  epoch : 77 here every batch size = 25
# 0.3354934896749191
# Validation error after  epoch : 77 here batch size = 25
# 0.31106641115521294
# Training error after  epoch : 78 here every batch size = 25
# 0.33386298418028093
# Validation error after  epoch : 78 here batch size = 25
# 0.3099637875714894
# Training error after  epoch : 79 here every batch size = 25
# 0.3322573541727203
# Validation error after  epoch : 79 here batch size = 25
# 0.3088882262462278
# Training error after  epoch : 80 here every batch size = 25
# 0.33067575616261424
# Validation error after  epoch : 80 here batch size = 25
# 0.3078389009821055
# Training error after  epoch : 81 here every batch size = 25
# 0.32911738880374386
# Validation error after  epoch : 81 here batch size = 25
# 0.30681502499200947
# Training error after  epoch : 82 here every batch size = 25
# 0.3275814904226869
# Validation error after  epoch : 82 here batch size = 25
# 0.30581584847778176
# Training error after  epoch : 83 here every batch size = 25
# 0.3260673367041645
# Validation error after  epoch : 83 here batch size = 25
# 0.3048406563744117
# Training error after  epoch : 84 here every batch size = 25
# 0.3245742385215856
# Validation error after  epoch : 84 here batch size = 25
# 0.303888766247276
# Training error after  epoch : 85 here every batch size = 25
# 0.32310153990290436
# Validation error after  epoch : 85 here batch size = 25
# 0.3029595263311431
# Training error after  epoch : 86 here every batch size = 25
# 0.32164861612267975
# Validation error after  epoch : 86 here batch size = 25
# 0.302052313700663
# Training error after  epoch : 87 here every batch size = 25
# 0.32021487191193637
# Validation error after  epoch : 87 here batch size = 25
# 0.3011665325629558
# Training error after  epoch : 88 here every batch size = 25
# 0.3187997397780798
# Validation error after  epoch : 88 here batch size = 25
# 0.3003016126637026
# Training error after  epoch : 89 here every batch size = 25
# 0.31740267842769826
# Validation error after  epoch : 89 here batch size = 25
# 0.2994570077988574
# Training error after  epoch : 90 here every batch size = 25
# 0.31602317128562424
# Validation error after  epoch : 90 here batch size = 25
# 0.2986321944247284
# Training error after  epoch : 91 here every batch size = 25
# 0.3146607251041171
# Validation error after  epoch : 91 here batch size = 25
# 0.29782667035974386
# Training error after  epoch : 92 here every batch size = 25
# 0.31331486865646785
# Validation error after  epoch : 92 here batch size = 25
# 0.29703995357172663
# Training error after  epoch : 93 here every batch size = 25
# 0.3119851515097445
# Validation error after  epoch : 93 here batch size = 25
# 0.29627158104495543
# Training error after  epoch : 94 here every batch size = 25
# 0.31067114287175457
# Validation error after  epoch : 94 here batch size = 25
# 0.2955211077217008
# Training error after  epoch : 95 here every batch size = 25
# 0.3093724305076494
# Validation error after  epoch : 95 here batch size = 25
# 0.2947881055132966
# Training error after  epoch : 96 here every batch size = 25
# 0.3080886197219013
# Validation error after  epoch : 96 here batch size = 25
# 0.29407216237614103
# Training error after  epoch : 97 here every batch size = 25
# 0.306819332401668
# Validation error after  epoch : 97 here batch size = 25
# 0.29337288144832935
# Training error after  epoch : 98 here every batch size = 25
# 0.30556420611782303
# Validation error after  epoch : 98 here batch size = 25
# 0.2926898802428986
# Training error after  epoch : 99 here every batch size = 25
# 0.30432289328016454
# Validation error after  epoch : 99 here batch size = 25
# 0.29202278989392316
# Training error after  epoch : 100 here every batch size = 25
# 0.30309506034354244
# Validation error after  epoch : 100 here batch size = 25
# 0.2913712544519337
# Training Error for 100th epoch for Trail Number : 4
# Training error after  epoch : 1 here every batch size = 25
# 2.1425586587045826
# Validation error after  epoch : 1 here batch size = 25
# 1.9113613229425404
# Training error after  epoch : 2 here every batch size = 25
# 1.7414076426417948
# Validation error after  epoch : 2 here batch size = 25
# 1.5853085456946099
# Training error after  epoch : 3 here every batch size = 25
# 1.4597092613096712
# Validation error after  epoch : 3 here batch size = 25
# 1.3543984190897964
# Training error after  epoch : 4 here every batch size = 25
# 1.2606206916791933
# Validation error after  epoch : 4 here batch size = 25
# 1.1896406884052373
# Training error after  epoch : 5 here every batch size = 25
# 1.1174919432166088
# Validation error after  epoch : 5 here batch size = 25
# 1.0691218204035173
# Training error after  epoch : 6 here every batch size = 25
# 1.0113796982883607
# Validation error after  epoch : 6 here batch size = 25
# 0.9780915391233603
# Training error after  epoch : 7 here every batch size = 25
# 0.9300243728480782
# Validation error after  epoch : 7 here batch size = 25
# 0.907167507075823
# Training error after  epoch : 8 here every batch size = 25
# 0.8657044081153185
# Validation error after  epoch : 8 here batch size = 25
# 0.8503845696811831
# Training error after  epoch : 9 here every batch size = 25
# 0.8134978035610518
# ...
# 0.44880861703335156
# Training error after  epoch : 51 here every batch size = 25
# 0.37925379523413305
# Validation error after  epoch : 51 here batch size = 25
# 0.4465735993775657
# Training error after  epoch : 52 here every batch size = 25
# 0.3764537831096562
# Validation error after  epoch : 52 here batch size = 25
# 0.4444144009364465
# Training error after  epoch : 53 here every batch size = 25
# 0.3737276947531684
# Validation error after  epoch : 53 here batch size = 25
# 0.4423274242730105
# Training error after  epoch : 54 here every batch size = 25
# 0.3710719586039104
# Validation error after  epoch : 54 here batch size = 25
# 0.44030929124993506
# Training error after  epoch : 55 here every batch size = 25
# 0.3684832291443607
# Validation error after  epoch : 55 here batch size = 25
# 0.4383568258910029
# Training error after  epoch : 56 here every batch size = 25
# 0.3659583695067966
# Validation error after  epoch : 56 here batch size = 25
# 0.43646703903536627
# Training error after  epoch : 57 here every batch size = 25
# 0.3634944357572938
# Validation error after  epoch : 57 here batch size = 25
# 0.4346371145451053
# Training error after  epoch : 58 here every batch size = 25
# 0.36108866264919
# Validation error after  epoch : 58 here batch size = 25
# 0.4328643968641233
# Training error after  epoch : 59 here every batch size = 25
# 0.3587384506699276
# Validation error after  epoch : 59 here batch size = 25
# 0.43114637975749026
# Training error after  epoch : 60 here every batch size = 25
# 0.35644135423153656
# Validation error after  epoch : 60 here batch size = 25
# 0.42948069608609674
# Training error after  epoch : 61 here every batch size = 25
# 0.3541950708768035
# Validation error after  epoch : 61 here batch size = 25
# 0.4278651084928963
# Training error after  epoch : 62 here every batch size = 25
# 0.35199743139126116
# Validation error after  epoch : 62 here batch size = 25
# 0.4262975008948681
# Training error after  epoch : 63 here every batch size = 25
# 0.3498463907261683
# Validation error after  epoch : 63 here batch size = 25
# 0.42477587068977
# Training error after  epoch : 64 here every batch size = 25
# 0.3477400196502318
# Validation error after  epoch : 64 here batch size = 25
# 0.423298321599288
# Training error after  epoch : 65 here every batch size = 25
# 0.3456764970583347
# Validation error after  epoch : 65 here batch size = 25
# 0.4218630570807522
# Training error after  epoch : 66 here every batch size = 25
# 0.34365410287443454
# Validation error after  epoch : 66 here batch size = 25
# 0.4204683742485091
# Training error after  epoch : 67 here every batch size = 25
# 0.34167121149329716
# Validation error after  epoch : 67 here batch size = 25
# 0.4191126582536084
# Training error after  epoch : 68 here every batch size = 25
# 0.33972628571211844
# Validation error after  epoch : 68 here batch size = 25
# 0.41779437707690564
# Training error after  epoch : 69 here every batch size = 25
# 0.3378178711085788
# Validation error after  epoch : 69 here batch size = 25
# 0.4165120766961758
# Training error after  epoch : 70 here every batch size = 25
# 0.3359445908265557
# Validation error after  epoch : 70 here batch size = 25
# 0.4152643765925416
# Training error after  epoch : 71 here every batch size = 25
# 0.33410514073481584
# Validation error after  epoch : 71 here batch size = 25
# 0.4140499655655714
# Training error after  epoch : 72 here every batch size = 25
# 0.3322982849275384
# Validation error after  epoch : 72 here batch size = 25
# 0.41286759782988286
# Training error after  epoch : 73 here every batch size = 25
# 0.33052285153862415
# Validation error after  epoch : 73 here batch size = 25
# 0.41171608936911225
# Training error after  epoch : 74 here every batch size = 25
# 0.32877772884447054
# Validation error after  epoch : 74 here batch size = 25
# 0.41059431452571876
# Training error after  epoch : 75 here every batch size = 25
# 0.3270618616322982
# Validation error after  epoch : 75 here batch size = 25
# 0.4095012028073743
# Training error after  epoch : 76 here every batch size = 25
# 0.325374247813246
# Validation error after  epoch : 76 here batch size = 25
# 0.4084357358926728
# Training error after  epoch : 77 here every batch size = 25
# 0.3237139352613488
# Validation error after  epoch : 77 here batch size = 25
# 0.40739694482063304
# Training error after  epoch : 78 here every batch size = 25
# 0.32208001886121823
# Validation error after  epoch : 78 here batch size = 25
# 0.4063839073499953
# Training error after  epoch : 79 here every batch size = 25
# 0.3204716377487502
# Validation error after  epoch : 79 here batch size = 25
# 0.40539574547565516
# Training error after  epoch : 80 here every batch size = 25
# 0.31888797273056363
# Validation error after  epoch : 80 here batch size = 25
# 0.40443162309076697
# Training error after  epoch : 81 here every batch size = 25
# 0.31732824386909253
# Validation error after  epoch : 81 here batch size = 25
# 0.4034907437841006
# Training error after  epoch : 82 here every batch size = 25
# 0.3157917082213693
# Validation error after  epoch : 82 here batch size = 25
# 0.4025723487631678
# Training error after  epoch : 83 here every batch size = 25
# 0.31427765772053357
# Validation error after  epoch : 83 here batch size = 25
# 0.40167571489447296
# Training error after  epoch : 84 here every batch size = 25
# 0.3127854171900086
# Validation error after  epoch : 84 here batch size = 25
# 0.4008001528529796
# Training error after  epoch : 85 here every batch size = 25
# 0.3113143424811128
# Validation error after  epoch : 85 here batch size = 25
# 0.3999450053735603
# Training error after  epoch : 86 here every batch size = 25
# 0.309863818725612
# Validation error after  epoch : 86 here batch size = 25
# 0.39910964559779016
# Training error after  epoch : 87 here every batch size = 25
# 0.3084332586953983
# Validation error after  epoch : 87 here batch size = 25
# 0.3982934755099899
# Training error after  epoch : 88 here every batch size = 25
# 0.3070221012620948
# Validation error after  epoch : 88 here batch size = 25
# 0.39749592445691045
# Training error after  epoch : 89 here every batch size = 25
# 0.3056298099499492
# Validation error after  epoch : 89 here batch size = 25
# 0.39671644774589365
# Training error after  epoch : 90 here every batch size = 25
# 0.30425587157587825
# Validation error after  epoch : 90 here batch size = 25
# 0.3959545253167463
# Training error after  epoch : 91 here every batch size = 25
# 0.3028997949710003
# Validation error after  epoch : 91 here batch size = 25
# 0.39520966048292977
# Training error after  epoch : 92 here every batch size = 25
# 0.3015611097784058
# Validation error after  epoch : 92 here batch size = 25
# 0.39448137873799666
# Training error after  epoch : 93 here every batch size = 25
# 0.3002393653223137
# Validation error after  epoch : 93 here batch size = 25
# 0.39376922662351616
# Training error after  epoch : 94 here every batch size = 25
# 0.2989341295440976
# Validation error after  epoch : 94 here batch size = 25
# 0.39307277065499774
# Training error after  epoch : 95 here every batch size = 25
# 0.29764498800100764
# Validation error after  epoch : 95 here batch size = 25
# 0.3923915963025857
# Training error after  epoch : 96 here every batch size = 25
# 0.2963715429236894
# Validation error after  epoch : 96 here batch size = 25
# 0.39172530702351976
# Training error after  epoch : 97 here every batch size = 25
# 0.29511341232889
# Validation error after  epoch : 97 here batch size = 25
# 0.3910735233435754
# Training error after  epoch : 98 here every batch size = 25
# 0.2938702291839718
# Validation error after  epoch : 98 here batch size = 25
# 0.3904358819848895
# Training error after  epoch : 99 here every batch size = 25
# 0.29264164062009973
# Validation error after  epoch : 99 here batch size = 25
# 0.38981203503775214
# Training error after  epoch : 100 here every batch size = 25
# 0.2914273071911589
# Validation error after  epoch : 100 here batch size = 25
# 0.3892016491741138
#
#
# Final Training Errors after 5 trails and 100 Epocs :
# [2.1389176688535296, 1.7505153020801207, 1.4810240903301577, 1.2864411340340811, 1.1427827939013036, 1.0342707547147414, 0.9503973992901135, 0.8840722801886401, 0.8304599546773858, 0.7862320562351475, 0.7490733961752234, 0.7173523924443337, 0.6899005331682876, 0.6658649301017995, 0.6446099820633214, 0.6256518745927957, 0.6086148312949267, 0.5932016438178759, 0.5791735300283094, 0.5663360978433474, 0.5545293425298344, 0.5436203509439367, 0.5334978601555246, 0.524068116043423, 0.5152516647996123, 0.5069808289457022, 0.4991976957954638, 0.49185249642841794, 0.484902286942538, 0.4783098669449987, 0.47204288653882864, 0.4660731047304869, 0.46037577066759156, 0.45492910537211223, 0.44971386630766774, 0.44471298065499576, 0.43991123587816244, 0.43529501826532746, 0.4308520917781343, 0.42657141085521, 0.4224429618689392, 0.41845762879001575, 0.4146070793151196, 0.41088366829237044, 0.40728035576183697, 0.40379063733340037, 0.40040848496636916, 0.39712829650579484, 0.39394485257835193, 0.3908532796628607, 0.3878490183326417, 0.38492779582321685, 0.38208560221311066, 0.3793186696205372, 0.3766234539171225, 0.37399661854363736, 0.37143502008384865, 0.36893569531268006, 0.3664958494853917, 0.3641128456766854, 0.361784195013745, 0.35950754767619203, 0.3572806845597736, 0.35510150952002023, 0.352968042127895, 0.35087841088217925, 0.34883084683353627, 0.34682367758331056, 0.3448553216265699, 0.3429242830139519, 0.34102914631084863, 0.3391685718355485, 0.33734129116036216, 0.3355461028616076, 0.33378186850576425, 0.3320475088602187, 0.33034200031788474, 0.3286643715256593, 0.32701370020721515, 0.3253891101710723, 0.3237897684952569, 0.3222148828801737, 0.3206636991615964, 0.3191354989759545, 0.31762959757031745, 0.31614534174973075, 0.31468210795478957, 0.3132393004625491, 0.31181634970411837, 0.31041271069249793, 0.3090278615544591, 0.30766130216048204, 0.3063125528470097, 0.30498115322548613, 0.30366666107289114, 0.3023686512986916, 0.3010867149833642, 0.2998204584838577, 0.2985695026015775, 0.2973334818086978, 2.0641973041330934, 1.6843316819809606, 1.4202310092764239, 1.233239711992747, 1.0980232578794147, 0.9971477640741055, 0.9193689457370462, 0.8575765065703634, 0.80721795736433, 0.7652996079356705, 0.7297884265606432, 0.6992583092312898, 0.672678908799203, 0.6492865834559725, 0.6285030348523668, 0.6098822863756028, 0.5930750327971669, 0.577803990985472, 0.563846435367248, 0.5510215591724886, 0.5391811603404597, 0.5282026707277859, 0.5179838704335875, 0.5084388349840343, 0.49949479761641524, 0.49108969897686433, 0.4831702583637952, 0.4756904440418288, 0.46861025121096594, 0.4618947188074164, 0.4555131329534151, 0.4494383772494495, 0.44364639937342043, 0.43811577043431255, 0.4328273188103491, 0.4277638242124772, 0.42290976077065473, 0.4182510802793422, 0.41377502853695036, 0.40946998910472504, 0.4053253498933285, 0.40133138883498504, 0.3974791755713552, 0.3937604866240574, 0.39016773194713483, 0.3866938911120715, 0.38333245766366025, 0.38007739042226163, 0.3769230707047699, 0.3738642646005665, 0.37089608957581827, 0.3680139847943583, 0.3652136846397714, 0.36249119500420596, 0.359842771977338, 0.3572649026258343, 0.3547542876013634, 0.35230782535507854, 0.34992259776985346, 0.34759585704935786, 0.34532501372627106, 0.3431076256712907, 0.34094138800072854, 0.3388241237939735, 0.33675377554338853, 0.3347283972686719, 0.3327461472356974, 0.330805281226602, 0.3289041463136357, 0.32704117509422026, 0.3252148803489019, 0.32342385008758273, 0.3216667429526317, 0.3199422839503342, 0.31824926048464386, 0.3165865186694689, 0.314952959897728, 0.31334753764724665, 0.3117692545052037, 0.3102171593943443, 0.3086903449855347, 0.30718794528249105, 0.3057091333656457, 0.3042531192831745, 0.30281914807815513, 0.3014064979417181, 0.3000144784828615, 0.29864242910633954, 0.2972897174907198, 0.29595573815934517, 0.2946399111374933, 0.29334168068957733, 0.29206051413071316, 0.2907959007074191, 0.28954735054264336, 0.28831439364067896, 0.2870965789478813, 0.28 ...
#
#
# Final Validation Errors after 5 trails and 100 Epocs :
# [1.9125154055417166, 1.5924636016003502, 1.363394402275896, 1.1961489703292845, 1.071397832714997, 0.97628544695881, 0.9021490164840081, 0.8430769465369171, 0.7950003331260395, 0.7550974450923743, 0.7213939227586417, 0.6924919719844563, 0.6673868140214806, 0.6453427668031679, 0.6258100023725772, 0.608368780331831, 0.5926920179693398, 0.5785199795645898, 0.5656429400585925, 0.5538891063695494, 0.5431160340394321, 0.5332043990669036, 0.5240533838000347, 0.5155771898765835, 0.507702353334883, 0.5003656414480133, 0.49351237910398743, 0.48709509797847983, 0.4810724325053357, 0.47540820780105525, 0.47007067942074426, 0.4650318951610615, 0.4602671564352683, 0.4557545619469041, 0.4514746201192672, 0.44740991944396696, 0.443544847906417, 0.4398653541478767, 0.43635874418373083, 0.43301350841939046, 0.429819174458052, 0.42676618182483594, 0.4238457752699899, 0.4210499137798567, 0.41837119283137525, 0.4158027777829026, 0.4133383466074085, 0.41097204044834, 0.4086984207175155, 0.40651243166164575, 0.4044093675025619, 0.40238484340884995, 0.4004347696861552, 0.3985553286825367, 0.3967429539964896, 0.3949943116509168, 0.3933062829586354, 0.3916759488559137, 0.39010057552182575, 0.38857760113448636, 0.3871046236418435, 0.38567938944587365, 0.3842997829157625, 0.38296381665882406, 0.3816696224882382, 0.3804154430347698, 0.379199623955966, 0.378020606701303, 0.3768769217956918, 0.3757671826069171, 0.3746900795651507, 0.3736443748048341, 0.3726288972010503, 0.37164253777411943, 0.3706842454375953, 0.3697530230661769, 0.3688479238613016, 0.36796804799338045, 0.3671125395007862, 0.3662805834268144, 0.36547140317692295, 0.36468425807960064, 0.3639184411352385, 0.363173276938362, 0.3624481197595392, 0.3617423517741989, 0.3610553814264733, 0.36038664191702674, 0.3597355898046355, 0.3591017037120494, 0.3584844831273894, 0.35788344729302, 0.3572981341744787, 0.35672809950264733, 0.35617291588291505, 0.3556321719656109, 0.35510547167246953, 0.35459243347435204, 0.35409268971586044, 0.3536058859828738, 1.8696092190007227, 1.5659580310972172, 1.3501008853245426, 1.1942555930050553, 1.0789623804352295, 0.9911366091805011, 0.9222811385982268, 0.866889220228893, 0.8213333215439198, 0.7831625917287449, 0.75067299304791, 0.7226455917374645, 0.6981855631211635, 0.6766211087824141, 0.6574382686101259, 0.6402376088270136, 0.6247045677397233, 0.6105885762185469, 0.5976879924224917, 0.5858390094767093, 0.574907356347712, 0.5647820112175357, 0.5553703937132098, 0.546594660192803, 0.5383888307428208, 0.53069654814772, 0.5234693197638604, 0.5166651300184181, 0.5102473384673654, 0.5041837987300893, 0.4984461490015255, 0.493009236499384, 0.48785064705232695, 0.4829503177538419, 0.47829021570688846, 0.47385406975424393, 0.4696271450252298, 0.4655960523577775, 0.4617485863487329, 0.45807358707676643, 0.45456082153130944, 0.451200881543095, 0.4479850956038905, 0.4449054524272444, 0.44195453447005406, 0.439125459929819, 0.4364118319717879, 0.43380769413653325, 0.43130749104112204, 0.42890603362293633, 0.4265984682894755, 0.42438024943404146, 0.4222471148590579, 0.42019506371823895, 0.4182203366477764, 0.41631939780670635, 0.414488918588912, 0.4127257628049473, 0.41102697316194664, 0.40938975889516216, 0.40781148442586196, 0.4062896589380439, 0.40482192678123724, 0.40340605861903506, 0.40203994325334563, 0.4007215800630015, 0.3994490720026313, 0.3982206191138203, 0.397034512505764, 0.395889128767039, 0.394782924773897, 0.39371443286376434, 0.3926822563454828, 0.3916850653203297, 0.39072159279007634, 0.3897906310303232, 0.3888910282091247, 0.3880216852325236, 0.3871815528000741, 0.3863696286547561, 0.3855849550129084, 0.38482661616091435, 0.38409373620640624, 0.3833854769726952, 0.38270103602600514, 0.38203964482588815, 0.3814005669899434, 0.38078309666463994, 0.3801865569946738, 0.37961029868387514, 0.37905369864120897, 0.37851615870591504, 0.3779971044462815, 0.37749598402697315, 0.37701226714021646, 0.37654544399650375, 0.3760950243708103, 0.37566053670061605, 0.375241527 ...
#
#
# Plots are started to Generate In Figures Folder :
#
#
# Plots are Generated Successfully In Figures folder

# %%
e, o = forward_pass(X[4000: ], W, V, Y[4000:])
cnt = 0
for o_, y_ in zip(o, Y[4000:]):
    if np.argmax(o_) == np.argmax(y_):
        cnt += 1
print(cnt)
# Out:
# 907

# %%
print(f'Testing Accuracy = {cnt / 1000 * 100}%')
# Out:
# Testing Accuracy = 90.7%

# %% [markdown]
# **Inferences**
#
#
# ---
# The neural network performs forward and backward pass for training. In backward pass the gradient update happens after the whole batch has been processed. The gradient update is calculated to be the mean of gradient update by each input sample. At the end of each epoch validation data is tested to find validation accuracy.
#
#
#
# Initially the cross-entropy loss was very high and it declined to a very low value in training(\~0.27) and validation(~0.3). From the graphs it is visible that both training and validation loss decreased after each epoch. When the learning rate is set to 0.1(10x) it is seen that similar trend is followed up to a certain epoch and then validation loss increases. This happens because now the neural network is overtrained and due to high learning rate the loss function oscillates without ever finding a good local minima. The network achieves good accuracy on testing data(90.7%). Also training loss is almost always lesser than validation loss because neural network's main objective is to minimize training loss.
